# %% [markdown]
# # Basic Dataset

# %%
import datetime
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append('/home/debjitparia/projects/cryptobot/features')
import dataset, calendar_util, fwd_return

# %%
start_date = pd.to_datetime('2022-01-10')
model_start_date = pd.to_datetime('2023-01-04')
end_date = pd.to_datetime('2025-02-28')
port_freq = '30min'  # protfolio rebalance frequency 
feature_bar = '30min' # Features made out of bars
label_bar = '30min' # 
fwd_return_interval = '15min'
local_timezone="Asia/Kolkata"

model_train_freq = 'monthly'
train_lookback_days = 512
feature_cols = ['sma_5',
 'sma_7',
 'sma_14',
 'sma_21',
 'sma_44',
 'sma_63',
 'sma_88',
 'sma_123',
 'sma_178',
 'sma_252',
 'open_diff',
 'high_diff',
 'low_diff',
 'close_diff',
 'prev_open_to_open',
 'prev_open_to_high',
 'prev_open_to_low',
 'prev_open_to_close',
 'prev_high_to_open',
 'prev_high_to_high',
 'prev_high_to_low',
 'prev_high_to_close',
 'prev_low_to_open',
 'prev_low_to_high',
 'prev_low_to_low',
 'prev_low_to_close',
 'prev_close_to_open',
 'prev_close_to_high',
 'prev_close_to_low',
 'prev_close_to_close',
 'ret_1',
 'ret_2',
 'ret_3',
 'ret_4',
 'ret_5',
 'ret_6',
 'ret_7',
 'ret_8',
 'ret_9',
 'ret_10',
 'ret_11',
 'ret_12',
 'ret_13',
 'ret_14',
 'ret_15',
 'ret_16',
 'ret_17',
 'ret_18',
 'ret_19',
 'ret_20',
 'ret_21',
 'ret_22',
 'ret_23',
 'ret_24',
 'ret_25',
 'ret_26',
 'ret_27',
 'ret_28',
 'ret_29',
 'ret_30',
 'ema_close_14',
 'ema_close_21',
 'ema_close_30',
 'ema_close_60',
 'ema_close_100',
 'ema_close_150',
 'ema_close_200',
 'plus_di_14',
 'minus_di_14',
 'adx_14',
 'plus_di_21',
 'minus_di_21',
 'adx_21',
 'plus_di_30',
 'minus_di_30',
 'adx_30',
 'plus_di_60',
 'minus_di_60',
 'adx_60',
 'plus_di_100',
 'minus_di_100',
 'adx_100',
 'plus_di_150',
 'minus_di_150',
 'adx_150',
 'plus_di_200',
 'minus_di_200',
 'adx_200',
 'eom_raw',
 'eom_ema_14',
 'eom_ema_21',
 'eom_ema_30',
 'eom_ema_60',
 'eom_ema_100',
 'eom_ema_150',
 'eom_ema_200',
 'adl_raw',
 'adl_ema_14',
 'adl_ema_21',
 'adl_ema_30',
 'adl_ema_60',
 'adl_ema_100',
 'adl_ema_150',
 'adl_ema_200',
 'cci_raw',
 'cci_ema_14',
 'cci_ema_21',
 'cci_ema_30',
 'cci_ema_60',
 'cci_ema_100',
 'cci_ema_150',
 'cci_ema_200',
 'l_atr_14',
 'r_atr_14',
 'l_atr_21',
 'r_atr_21',
 'l_atr_30',
 'r_atr_30',
 'l_atr_60',
 'r_atr_60',
 'l_atr_100',
 'r_atr_100',
 'l_atr_150',
 'r_atr_150',
 'l_atr_200',
 'r_atr_200',
 'chaikin_raw_2_7',
 'chaikin_raw_4_10',
 'chaikin_raw_6_15',
 'chaikin_raw_12_30',
 'chaikin_raw_20_50',
 'chaikin_raw_30_75',
 'chaikin_raw_40_100',
 'mfi_raw_14',
 'mfi_raw_21',
 'mfi_raw_30',
 'mfi_raw_60',
 'mfi_raw_100',
 'mfi_raw_150',
 'mfi_raw_200',
 'obv_ema_14',
 'obv_ema_21',
 'obv_ema_30',
 'obv_ema_60',
 'obv_ema_100',
 'obv_ema_150',
 'obv_ema_200',
 'efi_ema_14',
 'efi_ema_21',
 'efi_ema_30',
 'efi_ema_60',
 'efi_ema_100',
 'efi_ema_150',
 'efi_ema_200',
 'bbands_upper_raw_14',
 'bbands_lower_raw_14',
 'bbands_upper_raw_21',
 'bbands_lower_raw_21',
 'bbands_upper_raw_30',
 'bbands_lower_raw_30',
 'bbands_upper_raw_60',
 'bbands_lower_raw_60',
 'bbands_upper_raw_100',
 'bbands_lower_raw_100',
 'bbands_upper_raw_150',
 'bbands_lower_raw_150',
 'bbands_upper_raw_200',
 'bbands_lower_raw_200',
 'macd_12_26',
 'macd_7_14',
 'macd_10_21',
 'macd_15_30',
 'macd_30_60',
 'macd_50_100',
 'macd_75_150',
 'macd_100_200',
 'supertrend_14_2',
 'supertrend_21_2',
 'supertrend_30_2',
 'supertrend_60_2',
 'supertrend_100_2',
 'supertrend_150_2',
 'supertrend_200_2',
 'vwap',
 'rsi_14',
 'rsi_21',
 'rsi_30',
 'rsi_60',
 'rsi_100',
 'rsi_150',
 'rsi_200',]
label_col = 'Label'

symbols = ['BTCUSDT', 'ETHUSDT', 'SOLUSDT', 'XRPUSDT', 'BNBUSDT']

# %%
import pandas as pd
from datetime import datetime
from joblib import Parallel, delayed
import dataset, label  # your dataset.py with train_data()
import calendar_util  # for get_training_dates

def _train_data_task(symbol, date, feature_bar, port_freq, label_bar, local_timezone):
    """
    Helper task to call train_data safely.
    """
    try:
        label_df = label.label_data(symbol, date, port_freq, label_bar, local_timezone)
        train_df = dataset.train_data(symbol, date, port_freq, feature_bar, local_timezone)
        df = train_df.merge(label_df, on = ['timestamp', 'symbol'])
        if df is not None and not df.empty:
            return df
    except Exception as e:
        print(f"[ERROR] train_data failed for {symbol} on {date}: {e}")
    return None

def create_multi_day_dataset(symbols, dates, port_freq, feature_bar, label_bar, local_timezone="Asia/Kolkata", nproc=4):
    """
    Create combined dataset for multiple symbols and dates in parallel using joblib.

    Parameters
    ----------
    symbols : str or list[str]
        Single symbol or list of trading symbols.
    dates : pd.DatetimeIndex, list, or list-like of dates
        Dates to collect data for.
    port_freq : str
        Interval string, e.g. '15min', '30min'.
    local_timezone : str
        Timezone string.
    nproc : int
        Number of parallel workers.

    Returns
    -------
    pd.DataFrame
        Combined DataFrame of all training data.
    """
    # Normalize symbols and dates to lists
    if hasattr(dates, "__iter__") and not isinstance(dates, (str, bytes)):
        dates = [d.date() for d in pd.to_datetime(dates)]
    else:
        dates = [pd.to_datetime(dates).date()]
    if isinstance(symbols, str):
        symbols = [symbols]
    if isinstance(dates, (pd.DatetimeIndex, list, tuple)):
        dates = list(pd.to_datetime(dates).date)
    else:
        # single date input
        dates = [pd.to_datetime(dates).date()]


    # Create all (symbol, date) pairs
    tasks = [(symbol, date, port_freq, feature_bar, label_bar, local_timezone) for symbol in symbols for date in dates]

    results = Parallel(n_jobs=nproc, backend='loky')(
        delayed(_train_data_task)(symbol, date, port_freq, feature_bar, label_bar, local_timezone) for symbol, date, port_freq, feature_bar, label_bar, local_timezone in tasks
    )

    # Filter out None or empty results
    results = [df for df in results if df is not None and not df.empty]

    if not results:
        print("[WARN] No data collected for any symbol-date pair.")
        return pd.DataFrame()

    combined_df = pd.concat(results, ignore_index=True)
    print(f"[INFO] Combined dataset contains {len(combined_df)} rows from {len(symbols)} symbols and {len(dates)} dates.")
    return combined_df


def get_train_data(df, target_date, lookback_days, lag=2, model_train_freq="weekly"):
    """
    Slice training data from df based on lookback window and lag.

    Parameters
    ----------
    df : pd.DataFrame
        The full dataset containing a 'timestamp' column.
    target_date : datetime or str
        The date to predict for (exclusive from training set).
    lookback_days : int
        How many days to look back for training data.
    lag : int
        Gap (in days) between the last training date and target date.
    model_train_freq : str
        Frequency passed to `calendar_util.get_training_dates`.

    Returns
    -------
    pd.DataFrame
        The filtered training dataset.
    """
    target_date = pd.to_datetime(target_date).date()
    df['date'] = pd.to_datetime(df['timestamp']).dt.date

    training_dates = calendar_util.get_training_dates(
        target_date, lookback_days, lag=lag, frequency=model_train_freq
    )
    return df[df['date'].isin(training_dates)].copy()

# %%
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm
import fwd_return


def _fwd_data_task(symbol, date, port_freq, fwd_return_interval, local_timezone):
    """
    Helper task to call fwd_return.fwd_data safely.
    """
    try:
        df = fwd_return.fwd_data(symbol, date, port_freq, fwd_return_interval, local_timezone)
        if df is not None and not df.empty:
            return df
    except Exception as e:
        print(f"[ERROR] fwd_data failed for {symbol} on {date}: {e}")
    return None


def create_multi_day_fwd_returns(
    symbols, 
    dates, 
    port_freq, 
    fwd_return_interval, 
    local_timezone="Asia/Kolkata", 
    nproc=4
):
    """
    Collect forward return datasets for multiple symbols and dates in parallel.
    Falls back to sequential processing if nproc == 1.
    """
    # Ensure symbols is a list
    if isinstance(symbols, str):
        symbols = [symbols]

    # Normalize dates to list of datetime.date
    if hasattr(dates, "__iter__") and not isinstance(dates, (str, bytes)):
        dates = [pd.to_datetime(d).date() for d in dates]
    else:
        dates = [pd.to_datetime(dates).date()]

    # Create task list
    tasks = [(symbol, date) for symbol in symbols for date in dates]
    print(f"[INFO] Loaded {len(tasks)} tasks for forward return computation.")

    results = []

    if nproc == 1:
        # Sequential execution with tqdm
        for symbol, date in tqdm(tasks, desc="Fetching fwd_return data (sequential)"):
            df = _fwd_data_task(symbol, date, port_freq, fwd_return_interval, local_timezone)
            if df is not None and not df.empty:
                results.append(df)
    else:
        # Parallel execution with tqdm
        results = Parallel(n_jobs=nproc, backend="loky")(
            delayed(_fwd_data_task)(symbol, date, port_freq, fwd_return_interval, local_timezone)
            for symbol, date in tqdm(tasks, desc="Fetching fwd_return data (parallel)")
        )
        # Filter valid DataFrames
        results = [df for df in results if df is not None and not df.empty]

    if not results:
        print("[WARN] No forward return data collected.")
        return pd.DataFrame()

    combined_df = pd.concat(results, ignore_index=True)
    print(f"[INFO] Combined fwd_return dataset contains {len(combined_df)} rows.")
    return combined_df


def merge_with_fwd_returns(
    final_prediction_df, 
    symbols, 
    dates, 
    port_freq, 
    fwd_return_interval, 
    local_timezone="Asia/Kolkata", 
    nproc=4
):
    """
    Wrapper: fetch forward returns and merge into prediction dataframe.
    """
    fwd_ret_df = create_multi_day_fwd_returns(
        symbols, dates, port_freq, fwd_return_interval, local_timezone, nproc=nproc
    )
    if fwd_ret_df.empty:
        print("[WARN] No fwd_return data to merge.")
        return final_prediction_df

    merged = final_prediction_df.merge(fwd_ret_df, on=["timestamp", "symbol"])
    print(f"[INFO] Final merged dataframe contains {len(merged)} rows.")
    return merged

# %%
# dataset_df = _train_data_task('BTCUSDT', datetime(2023, 2, 4), feature_bar, port_freq, label_bar, local_timezone)
# merge_with_fwd_returns(dataset_df, ['BTCUSDT'], [datetime(2023, 2, 4, 15, 30)], port_freq, fwd_return_interval, local_timezone)

# %%
import pandas as pd

# Create a list of dates (date objects)
dates = pd.date_range(start=start_date, end=end_date, freq='D').date

# Now call with list of dates
dataset_df = create_multi_day_dataset(symbols, dates, port_freq, feature_bar, label_bar, nproc=8)
# dataset_df = merge_with_fwd_returns(dataset_df, symbols, dates, port_freq, fwd_return_interval, local_timezone)
# Out:
# [ERROR] train_data failed for BTCUSDT on 2023-03-26: Error in dataset.train_data (hash train_da_519a768e0cbe436234455d03417cc69c): Error in sma.get_sma_indicators (hash get_sma__a9a0b1d917dd8e7ebfd1e5b643561bcc): Error in dataloader.get_symbol_snapshot_bar (hash get_symb_536fa4ad5f31e0030147369be11f84c6): Not enough 1-minute bars to build a 30min candle for BTCUSDT ending at 2023-03-24 19:30:00+05:30.
# Expected 30, got 0.
# Possibly the latest candle is still forming — try again after the interval completes.
# See stderr log at: /home/debjitparia/Cache/cryptobot_fut/snapshot_bars/get_symb_536fa4ad5f31e0030147369be11f84c6/stderr.txt
# See stderr log at: /home/debjitparia/Cache/cryptobot_fut/sma_indicator/get_sma__a9a0b1d917dd8e7ebfd1e5b643561bcc/stderr.txt
# See stderr log at: /home/debjitparia/Cache/cryptobot_fut/train_data/train_da_519a768e0cbe436234455d03417cc69c/stderr.txt
# ...

# %%
# dataset_df =dataset_df[feature_cols + ['Fwd_Ret', 'timestamp']]

# %%
# numeric_cols = dataset_df.select_dtypes(include=['number']).columns.tolist()

# %%
# numeric_cols

# %%
model_train_dates = sorted(list(set([calendar_util.get_last_training_date(dt, frequency = model_train_freq) for dt in pd.date_range(start=model_start_date, end=end_date, freq='D')])))

# %%
model_prediction_dates = {}

for i, train_date in enumerate(model_train_dates):
    # Determine the start of prediction (day after training)
    pred_start = train_date

    # Determine the end of predictio
    if i + 1 < len(model_train_dates):
        pred_end = model_train_dates[i + 1]
    else:
        pred_end = end_date + pd.Timedelta(days=1)  # include last day

    # Generate prediction date range (exclude train_date itself)
    pred_dates = pd.date_range(start=pred_start, end=pred_end - pd.Timedelta(days=1), freq='D')

    model_prediction_dates[train_date] = pred_dates

# %%
import numpy as np
import pytz
from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Store forward prediction results
forward_predictions = {}

# RidgeCV + Bagging setup

from sklearn.linear_model import Ridge
from sklearn.ensemble import BaggingRegressor

# Base RidgeCV model
ridge_base = Ridge()

# Bagging wrapper (new API uses 'estimator')
ridge_bagging = BaggingRegressor(
    estimator=ridge_base,
    n_estimators=100,
    max_samples=0.7,
    max_features=0.5,
    bootstrap=True,
    bootstrap_features=False,
    n_jobs=-1,
    random_state=42
)

# Example model list — specify type explicitly
model_list = [
    # ("LR", "reg", LinearRegression()),
    ("Ridge_Bagging", "reg", ridge_bagging),
    ("LGBM_Regression", "reg", LGBMRegressor(
        n_estimators=128, learning_rate=0.01, max_depth=-1, random_state=42,
        min_child_samples=int(len(dataset_df) * 0.01), min_child_weight=0.01, num_leaves=8, n_jobs=8)
    )
]

# Threshold for classification target
CLASS_THRESH = 0  # example: predict if label > 0

for train_date in model_train_dates:
    print(f"\nTraining models for {train_date}")

    # In-sample training data
    train_data = get_train_data(dataset_df, train_date, train_lookback_days, lag=1)
    train_data = train_data.replace([np.inf, -np.inf], np.nan).fillna(0)

    X_train = train_data[feature_cols]
    y_train = train_data[label_col]

    if X_train.empty or y_train.empty:
        print("No training data found. Skipping...")
        continue

    y_train_cls = (y_train > CLASS_THRESH).astype(int)
    if y_train_cls.nunique() == 1:
        print("Skipping: constant feature(s) found.")
        continue

    # ---- Train & Collect Predictions ----
    preds_train_all = []
    for name, mtype, model in model_list:
        print(f"Training {name}...")

        if mtype == "clf":
            y_train_cls = (y_train > CLASS_THRESH).astype(int)
            model.fit(X_train, y_train_cls)
            y_pred_train = model.predict_proba(X_train)[:, 1]
        else:
            model.fit(X_train, y_train)
            y_pred_train = model.predict(X_train)

        preds_train_all.append(y_pred_train)

    # Ensemble prediction = mean of all model predictions
    y_pred_train_ensemble = np.mean(preds_train_all, axis=0)

    # In-sample metrics (regression metrics)
    r2 = r2_score(y_train, y_pred_train_ensemble)
    mse = mean_squared_error(y_train, y_pred_train_ensemble)
    mae = mean_absolute_error(y_train, y_pred_train_ensemble)

    print(f"In-sample R² Score: {r2:.10f}")
    print(f"In-sample MSE     : {mse:.10f}")
    print(f"In-sample MAE     : {mae:.10f}")

    # ---- OOS / Forward Predictions ----
    pred_dates = model_prediction_dates[train_date]
    if pred_dates.empty:
        continue

    ASIA_TZ = 'Asia/Kolkata'
    pred_dates = pred_dates.tz_localize(ASIA_TZ)

    mask = (
        (dataset_df['timestamp'] >= pred_dates.min()) &
        (dataset_df['timestamp'] <= pred_dates.max())
    )
    pred_df = dataset_df[mask].copy()
    pred_df = pred_df.replace([np.inf, -np.inf], np.nan).fillna(0)

    if pred_df.empty:
        print("No data available for forward prediction window.")
        continue

    X_pred = pred_df[feature_cols]
    y_true = pred_df[label_col] if label_col in pred_df else None

    preds_oos_all = []
    for name, mtype, model in model_list:
        if mtype == "clf":
            y_pred_oos = model.predict_proba(X_pred)[:, 1]
        else:
            y_pred_oos = model.predict(X_pred)
        preds_oos_all.append(y_pred_oos)

    y_pred_oos_ensemble = np.mean(preds_oos_all, axis=0)
    pred_df['Prediction'] = y_pred_oos_ensemble
    # Save predictions
    forward_predictions[train_date] = pred_df

    # OOS metrics
    if y_true is not None and not y_true.isnull().all():
        r2_oos = r2_score(y_true, y_pred_oos_ensemble)
        mse_oos = mean_squared_error(y_true, y_pred_oos_ensemble)
        mae_oos = mean_absolute_error(y_true, y_pred_oos_ensemble)
        print(f"OOS R² Score: {r2_oos:.10f}")
        print(f"OOS MSE     : {mse_oos:.10f}")
        print(f"OOS MAE     : {mae_oos:.10f}")
    else:
        print("Ground truth not available for OOS window.")
# Out:
# Training models for 2023-01-01
# Training Ridge_Bagging...
# Training LGBM_Regression...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032991 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 85435, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000045
# In-sample R² Score: 0.0062229368
# In-sample MSE     : 0.0000475184
# In-sample MAE     : 0.0042113406
# OOS R² Score: -0.0047965213
# OOS MSE     : 0.0000353219
# OOS MAE     : 0.0033443812
#
# Training models for 2023-02-01
# Training Ridge_Bagging...
# Training LGBM_Regression...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033093 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# ...

# %%
# Collect all prediction results
all_preds = []

for train_date, result in forward_predictions.items():
    temp_df = result[['timestamp', 'symbol', 'Label', 'Prediction']]
    # temp_df['timestamp'] = pd.to_datetime(temp_df['timestamp']).dt.tz_localize('Asia/Kolkata')
    # Merge with original dataset to bring in features
    # Append to final list
    all_preds.append(temp_df)

# Combine all into a single DataFrame
final_prediction_df = pd.concat(all_preds, ignore_index=True)

# Optional: sort by timestamp
final_prediction_df = final_prediction_df.sort_values(by='timestamp').reset_index(drop=True)

# %%
final_prediction_df
# Out:
#                        timestamp   symbol     Label  Prediction
# 0      2023-01-01 00:00:00+05:30  BTCUSDT  0.000040   -0.000090
# 1      2023-01-01 00:00:00+05:30  SOLUSDT -0.005994   -0.000347
# 2      2023-01-01 00:00:00+05:30  XRPUSDT -0.002337   -0.000349
# 3      2023-01-01 00:00:00+05:30  BNBUSDT  0.000000   -0.000120
# 4      2023-01-01 00:00:00+05:30  ETHUSDT -0.000483   -0.000147
# ...                          ...      ...       ...         ...
# 181805 2025-02-28 00:00:00+05:30  XRPUSDT  0.004427    0.000047
# 181806 2025-02-28 00:00:00+05:30  ETHUSDT  0.000903    0.000009
# 181807 2025-02-28 00:00:00+05:30  BTCUSDT  0.000724    0.000195
# 181808 2025-02-28 00:00:00+05:30  SOLUSDT -0.003814    0.000079
# 181809 2025-02-28 00:00:00+05:30  BNBUSDT -0.000296    0.000011
#
# [181810 rows x 4 columns]

# %%
dataloader. get_binance_klines('BTCUSDT', '1m', start_time, end_time, "Asia/Kolkata")

# %%
dates = pd.date_range(start=start_date, end=end_date, freq='D').date

final_prediction_df = merge_with_fwd_returns(
    final_prediction_df[['timestamp', 'symbol','Label', 'Prediction']], symbols, dates, port_freq, fwd_return_interval, local_timezone="Asia/Kolkata", nproc=1
)
# Out:
# [INFO] Loaded 5730 tasks for forward return computation.
# Fetching fwd_return data (sequential):  13%|███████████████▌                                                                                                           | 723/5730 [00:00<00:00, 7223.02it/s]
# [ERROR] fwd_data failed for BTCUSDT on 2023-03-24: Error in fwd_return.fwd_data (hash fwd_data_f7814ceda6e0e724a8b8cdd0cc69fcd3): Error in fwd_return.compute (hash compute_0bccb384727cbafbc4375f625a979da3): Error in dataloader.get_symbol_snapshot_bar (hash get_symb_de4a11794ba63b177142f191f23912f7): No 1-minute data returned for BTCUSDT between 2023-03-24 18:15:00+05:30 and 2023-03-24 18:30:00+05:30.
# See stderr log at: /home/debjitparia/Cache/cryptobot_fut/snapshot_bars/get_symb_de4a11794ba63b177142f191f23912f7/stderr.txt
# See stderr log at: /home/debjitparia/Cache/cryptobot_fut/fwd_ret/compute_0bccb384727cbafbc4375f625a979da3/stderr.txt
# ...

# %%
final_prediction_df

# %%
# final_prediction_df['True_val'].hist()

# %%
final_prediction_df['return'] = np.sign(final_prediction_df['Prediction']) * final_prediction_df['Fwd_Ret'] / len(symbols)
final_prediction_df['Hit'] = np.sign(final_prediction_df['Prediction']) * np.sign(final_prediction_df['Fwd_Ret'])

# %%
len(final_prediction_df[final_prediction_df['Hit'] > 0])/len(final_prediction_df)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Optional: Ensure DataFrame is sorted by time
final_prediction_df = final_prediction_df.sort_values(by='timestamp')

# Calculate cumulative returns
final_prediction_df['cumulative_return'] = final_prediction_df['return'].cumsum()

# Plot
plt.figure(figsize=(12, 6))
plt.plot(final_prediction_df['timestamp'], final_prediction_df['cumulative_return'], label='PnL Curve', color='blue')

# Formatting
plt.xlabel('Time')
plt.ylabel('Cumulative Return')
plt.title('Predicted Strategy PnL')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
