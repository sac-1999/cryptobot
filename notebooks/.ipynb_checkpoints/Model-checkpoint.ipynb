# %% [markdown]
# # Basic Dataset

# %%
import datetime
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append('/home/debjitparia/projects/cryptobot/features')
import dataset, calendar_util
# Out:
#       ret_1     ret_2     ret_3     ret_4     ret_5     ret_6     ret_7  \
# 0  0.001482 -0.002458 -0.001952 -0.001366  0.003333  0.017772 -0.001333
#
#       ret_8    ret_9    ret_10  ...    ret_23    ret_24    ret_25   ret_26  \
# 0 -0.001397  0.00868 -0.001587  ...  0.002806 -0.001201 -0.000873  0.00628
#
#      ret_27    ret_28    ret_29   ret_30   symbol                 timestamp
# 0  0.001129  0.000484 -0.001467 -0.00275  BTCUSDT 2025-04-23 15:30:00+05:30
#
# [1 rows x 32 columns]

# %%
start_date = pd.to_datetime('2022-01-10')
model_start_date = pd.to_datetime('2022-01-13')
end_date = pd.to_datetime('2022-02-28')
interval = '1h' 
feature_interval = '1h' 
fwd_pred_int = '1h'
model_train_freq = 'weekly'
train_lookback_days = 252
feature_cols = ['sma_5',
 'sma_7',
 'sma_14',
 'sma_21',
 'sma_44',
 'sma_63',
 'sma_88',
 'sma_123',
 'sma_178',
 'sma_252',
 'open_diff',
 'high_diff',
 'low_diff',
 'close_diff',
 'prev_open_to_open',
 'prev_open_to_high',
 'prev_open_to_low',
 'prev_open_to_close',
 'prev_high_to_open',
 'prev_high_to_high',
 'prev_high_to_low',
 'prev_high_to_close',
 'prev_low_to_open',
 'prev_low_to_high',
 'prev_low_to_low',
 'prev_low_to_close',
 'prev_close_to_open',
 'prev_close_to_high',
 'prev_close_to_low',
 'prev_close_to_close',
 'ret_1',
 'ret_2',
 'ret_3',
 'ret_4',
 'ret_5',
 'ret_6',
 'ret_7',
 'ret_8',
 'ret_9',
 'ret_10',
 'ret_11',
 'ret_12',
 'ret_13',
 'ret_14',
 'ret_15',
 'ret_16',
 'ret_17',
 'ret_18',
 'ret_19',
 'ret_20',
 'ret_21',
 'ret_22',
 'ret_23',
 'ret_24',
 'ret_25',
 'ret_26',
 'ret_27',
 'ret_28',
 'ret_29',
 'ret_30',
 'ema_close_14',
 'ema_close_21',
 'ema_close_30',
 'ema_close_60',
 'ema_close_100',
 'ema_close_150',
 'ema_close_200',
 'plus_di_14',
 'minus_di_14',
 'adx_14',
 'plus_di_21',
 'minus_di_21',
 'adx_21',
 'plus_di_30',
 'minus_di_30',
 'adx_30',
 'plus_di_60',
 'minus_di_60',
 'adx_60',
 'plus_di_100',
 'minus_di_100',
 'adx_100',
 'plus_di_150',
 'minus_di_150',
 'adx_150',
 'plus_di_200',
 'minus_di_200',
 'adx_200',
 'eom_raw',
 'eom_ema_14',
 'eom_ema_21',
 'eom_ema_30',
 'eom_ema_60',
 'eom_ema_100',
 'eom_ema_150',
 'eom_ema_200',
 'adl_raw',
 'adl_ema_14',
 'adl_ema_21',
 'adl_ema_30',
 'adl_ema_60',
 'adl_ema_100',
 'adl_ema_150',
 'adl_ema_200',
 'cci_raw',
 'cci_ema_14',
 'cci_ema_21',
 'cci_ema_30',
 'cci_ema_60',
 'cci_ema_100',
 'cci_ema_150',
 'cci_ema_200',
 'l_atr_14',
 'r_atr_14',
 'l_atr_21',
 'r_atr_21',
 'l_atr_30',
 'r_atr_30',
 'l_atr_60',
 'r_atr_60',
 'l_atr_100',
 'r_atr_100',
 'l_atr_150',
 'r_atr_150',
 'l_atr_200',
 'r_atr_200',
 'chaikin_raw_2_7',
 'chaikin_raw_4_10',
 'chaikin_raw_6_15',
 'chaikin_raw_12_30',
 'chaikin_raw_20_50',
 'chaikin_raw_30_75',
 'chaikin_raw_40_100',
 'mfi_raw_14',
 'mfi_raw_21',
 'mfi_raw_30',
 'mfi_raw_60',
 'mfi_raw_100',
 'mfi_raw_150',
 'mfi_raw_200',
 'obv_ema_14',
 'obv_ema_21',
 'obv_ema_30',
 'obv_ema_60',
 'obv_ema_100',
 'obv_ema_150',
 'obv_ema_200',
 'efi_ema_14',
 'efi_ema_21',
 'efi_ema_30',
 'efi_ema_60',
 'efi_ema_100',
 'efi_ema_150',
 'efi_ema_200',
 'bbands_upper_raw_14',
 'bbands_lower_raw_14',
 'bbands_upper_raw_21',
 'bbands_lower_raw_21',
 'bbands_upper_raw_30',
 'bbands_lower_raw_30',
 'bbands_upper_raw_60',
 'bbands_lower_raw_60',
 'bbands_upper_raw_100',
 'bbands_lower_raw_100',
 'bbands_upper_raw_150',
 'bbands_lower_raw_150',
 'bbands_upper_raw_200',
 'bbands_lower_raw_200',
 'macd_12_26',
 'macd_7_14',
 'macd_10_21',
 'macd_15_30',
 'macd_30_60',
 'macd_50_100',
 'macd_75_150',
 'macd_100_200',
 'supertrend_14_2',
 'supertrend_21_2',
 'supertrend_30_2',
 'supertrend_60_2',
 'supertrend_100_2',
 'supertrend_150_2',
 'supertrend_200_2',
 'vwap',
 'rsi_14',
 'rsi_21',
 'rsi_30',
 'rsi_60',
 'rsi_100',
 'rsi_150',
 'rsi_200',]
label_col = 'Fwd_Ret'

symbols = ['BTCUSDT', 'ETHUSDT']

# %%
import pandas as pd
from datetime import datetime
from joblib import Parallel, delayed
import dataset  # your dataset.py with train_data()
import calendar_util  # for get_training_dates

def _train_data_task(symbol, date, interval, feature_interval, fwd_pred_int, local_timezone):
    """
    Helper task to call train_data safely.
    """
    try:
        df = dataset.train_data(symbol, date, interval, feature_interval, fwd_pred_int, local_timezone)
        if df is not None and not df.empty:
            return df
    except Exception as e:
        print(f"[ERROR] train_data failed for {symbol} on {date}: {e}")
    return None

def create_multi_day_dataset(symbols, dates, interval, feature_interval, fwd_pred_int, local_timezone="Asia/Kolkata", nproc=4):
    """
    Create combined dataset for multiple symbols and dates in parallel using joblib.

    Parameters
    ----------
    symbols : str or list[str]
        Single symbol or list of trading symbols.
    dates : pd.DatetimeIndex, list, or list-like of dates
        Dates to collect data for.
    interval : str
        Interval string, e.g. '15min', '30min'.
    local_timezone : str
        Timezone string.
    nproc : int
        Number of parallel workers.

    Returns
    -------
    pd.DataFrame
        Combined DataFrame of all training data.
    """
    # Normalize symbols and dates to lists
    if hasattr(dates, "__iter__") and not isinstance(dates, (str, bytes)):
        dates = [d.date() for d in pd.to_datetime(dates)]
    else:
        dates = [pd.to_datetime(dates).date()]
    if isinstance(symbols, str):
        symbols = [symbols]
    if isinstance(dates, (pd.DatetimeIndex, list, tuple)):
        dates = list(pd.to_datetime(dates).date)
    else:
        # single date input
        dates = [pd.to_datetime(dates).date()]


    # Create all (symbol, date) pairs
    tasks = [(symbol, date, interval, feature_interval, fwd_pred_int, local_timezone) for symbol in symbols for date in dates]

    results = Parallel(n_jobs=nproc, backend='loky')(
        delayed(_train_data_task)(symbol, date, interval, feature_interval, fwd_pred_int, local_timezone) for symbol, date, interval, feature_interval, fwd_pred_int, local_timezone in tasks
    )

    # Filter out None or empty results
    results = [df for df in results if df is not None and not df.empty]

    if not results:
        print("[WARN] No data collected for any symbol-date pair.")
        return pd.DataFrame()

    combined_df = pd.concat(results, ignore_index=True)
    print(f"[INFO] Combined dataset contains {len(combined_df)} rows from {len(symbols)} symbols and {len(dates)} dates.")
    return combined_df


def get_train_data(df, target_date, lookback_days, lag=1, model_train_freq="weekly"):
    """
    Slice training data from df based on lookback window and lag.

    Parameters
    ----------
    df : pd.DataFrame
        The full dataset containing a 'timestamp' column.
    target_date : datetime or str
        The date to predict for (exclusive from training set).
    lookback_days : int
        How many days to look back for training data.
    lag : int
        Gap (in days) between the last training date and target date.
    model_train_freq : str
        Frequency passed to `calendar_util.get_training_dates`.

    Returns
    -------
    pd.DataFrame
        The filtered training dataset.
    """
    target_date = pd.to_datetime(target_date).date()
    df['date'] = pd.to_datetime(df['timestamp']).dt.date

    training_dates = calendar_util.get_training_dates(
        target_date, lookback_days, lag=lag, frequency=model_train_freq
    )
    return df[df['date'].isin(training_dates)].copy()

# %%
import pandas as pd

# Create a list of dates (date objects)
dates = pd.date_range(start=start_date, end=end_date, freq='D').date

# Now call with list of dates
dataset_df = create_multi_day_dataset(symbols, dates, interval, feature_interval, fwd_pred_int, nproc=6)
# Out:
# [INFO] Combined dataset contains 2400 rows from 2 symbols and 50 dates.

# %%
dataset_df
# Out:
#                      open_time                       close_time      open  \
# 0    2022-01-10 00:00:00+05:30 2022-01-10 00:59:59.999000+05:30  42234.81
# 1    2022-01-10 01:00:00+05:30 2022-01-10 01:59:59.999000+05:30  42602.69
# 2    2022-01-10 02:00:00+05:30 2022-01-10 02:59:59.999000+05:30  42490.03
# 3    2022-01-10 03:00:00+05:30 2022-01-10 03:59:59.999000+05:30  42409.00
# 4    2022-01-10 04:00:00+05:30 2022-01-10 04:59:59.999000+05:30  42434.73
# ...                        ...                              ...       ...
# 2395 2022-02-28 19:00:00+05:30 2022-02-28 19:59:59.999000+05:30   2621.94
# 2396 2022-02-28 20:00:00+05:30 2022-02-28 20:59:59.999000+05:30   2691.09
# 2397 2022-02-28 21:00:00+05:30 2022-02-28 21:59:59.999000+05:30   2790.34
# 2398 2022-02-28 22:00:00+05:30 2022-02-28 22:59:59.999000+05:30   2820.88
# 2399 2022-02-28 23:00:00+05:30 2022-02-28 23:59:59.999000+05:30   2806.64
#
#           high       low     close        volume  quote_asset_volume  \
# 0     42665.28  41861.94  42602.70    1830.69731        7.728508e+07
# 1     42786.70  42470.00  42490.03    1624.82551        6.921406e+07
# 2     42557.36  42368.00  42409.00     694.86250        2.950224e+07
# 3     42497.26  42280.00  42437.36     653.45811        2.768374e+07
# 4     42440.00  41766.43  41818.66    1110.53153        4.671985e+07
# ...        ...       ...       ...           ...                 ...
# 2395   2700.01   2607.38   2691.09   44689.62490        1.187509e+08
# 2396   2814.54   2690.13   2790.24  105578.95170        2.897187e+08
# 2397   2830.77   2790.18   2820.88   67483.20430        1.898917e+08
# 2398   2828.32   2789.00   2806.64   42368.47800        1.189933e+08
# 2399   2824.23   2790.00   2801.97   29687.75870        8.332693e+07
#
#       num_trades  taker_buy_base_volume  ...  supertrend_200_2      vwap  \
# 0          50641              940.54375  ...          0.027422 -0.049150
# 1          47476              782.82735  ...          0.016273 -0.051479
# 2          27418              367.64397  ...          0.014393 -0.053242
# 3          24567              348.30415  ...          0.015052 -0.052288
# 4          34251              476.47174  ...          0.000480 -0.067529
# ...          ...                    ...  ...               ...       ...
# 2395       57013            24534.31550  ...         -0.000395  0.020201
# 2396      136274            57070.62230  ...          0.047321  0.054403
# 2397       89554            34481.82680  ...          0.037082  0.064172
# 2398       59553            19962.22890  ...          0.032197  0.059210
# 2399       41212            13843.84200  ...          0.030584  0.057504
#
#          rsi_14     rsi_21     rsi_30     rsi_60    rsi_100    rsi_150  \
# 0     66.971694  54.219007  55.610152  54.441936  40.277722  42.381906
# 1     65.522573  60.710724  54.718212  51.003072  40.214785  42.531540
# 2     61.959359  65.158342  56.216865  49.980406  40.636340  42.619290
# 3     69.395760  63.722732  57.359531  50.514222  41.722003  43.459311
# 4     55.075911  47.031196  54.244518  48.021437  40.387642  41.995326
# ...         ...        ...        ...        ...        ...        ...
# 2395  64.064371  42.749228  47.065654  45.116005  57.369357  52.149718
# 2396  67.488191  52.261857  52.116374  50.095673  59.123612  53.477101
# 2397  74.397541  61.134443  52.610790  50.385533  59.198733  53.287560
# 2398  76.681338  69.114990  48.944742  50.484128  58.691313  53.092429
# 2399  75.910970  69.685635  49.528445  50.565851  58.530423  52.646288
#
#         rsi_200   Fwd_Ret
# 0     44.177757 -0.002645
# 1     44.040951 -0.001907
# 2     43.851755  0.000669
# 3     43.891908 -0.014579
# 4     43.176320  0.003142
# ...         ...       ...
# 2395  50.604160  0.036844
# 2396  51.524517  0.010981
# 2397  52.019507 -0.005048
# 2398  52.054577 -0.001664
# 2399  51.734014 -0.002555
#
# [2400 rows x 205 columns]

# %%
dataset_df =dataset_df[feature_cols + ['Fwd_Ret', 'timestamp']]

# %%
numeric_cols = dataset_df.select_dtypes(include=['number']).columns.tolist()

# %%
numeric_cols
# Out:
# ['open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'quote_asset_volume',
#  'num_trades',
#  'taker_buy_base_volume',
#  'taker_buy_quote_volume',
#  'sma_5',
#  'sma_7',
#  'sma_14',
#  'sma_21',
#  'sma_44',
#  'sma_63',
#  'sma_88',
#  'sma_123',
#  'sma_178',
#  'sma_252',
#  'open_diff',
#  'high_diff',
#  'low_diff',
#  'close_diff',
#  'prev_open_to_open',
#  'prev_open_to_high',
#  'prev_open_to_low',
#  'prev_open_to_close',
#  'prev_high_to_open',
#  'prev_high_to_high',
#  'prev_high_to_low',
#  'prev_high_to_close',
#  'prev_low_to_open',
#  'prev_low_to_high',
#  'prev_low_to_low',
#  'prev_low_to_close',
#  'prev_close_to_open',
#  'prev_close_to_high',
#  'prev_close_to_low',
#  'prev_close_to_close',
#  'ret_1',
#  'ret_2',
#  'ret_3',
#  'ret_4',
#  'ret_5',
#  'ret_6',
#  'ret_7',
#  'ret_8',
#  'ret_9',
#  'ret_10',
#  'ret_11',
#  'ret_12',
#  'ret_13',
#  'ret_14',
#  'ret_15',
#  'ret_16',
#  'ret_17',
#  'ret_18',
#  'ret_19',
#  'ret_20',
#  'ret_21',
#  'ret_22',
#  'ret_23',
#  'ret_24',
#  'ret_25',
#  'ret_26',
#  'ret_27',
#  'ret_28',
#  'ret_29',
#  'ret_30',
#  'ema_close_14',
#  'ema_close_21',
#  'ema_close_30',
#  'ema_close_60',
#  'ema_close_100',
#  'ema_close_150',
#  'ema_close_200',
#  'plus_di_14',
#  'minus_di_14',
#  'adx_14',
#  'plus_di_21',
#  'minus_di_21',
#  'adx_21',
#  'plus_di_30',
#  'minus_di_30',
#  'adx_30',
#  'plus_di_60',
#  'minus_di_60',
#  'adx_60',
#  'plus_di_100',
#  'minus_di_100',
#  'adx_100',
#  'plus_di_150',
#  'minus_di_150',
#  'adx_150',
#  'plus_di_200',
#  'minus_di_200',
#  'adx_200',
#  'eom_raw',
#  'eom_ema_14',
#  'eom_ema_21',
#  'eom_ema_30',
#  'eom_ema_60',
#  'eom_ema_100',
#  'eom_ema_150',
#  'eom_ema_200',
#  'adl_raw',
#  'adl_ema_14',
#  'adl_ema_21',
#  'adl_ema_30',
#  'adl_ema_60',
#  'adl_ema_100',
#  'adl_ema_150',
#  'adl_ema_200',
#  'cci_raw',
#  'cci_ema_14',
#  'cci_ema_21',
#  'cci_ema_30',
#  'cci_ema_60',
#  'cci_ema_100',
#  'cci_ema_150',
#  'cci_ema_200',
#  'l_atr_14',
#  'r_atr_14',
#  'l_atr_21',
#  'r_atr_21',
#  'l_atr_30',
#  'r_atr_30',
#  'l_atr_60',
#  'r_atr_60',
#  'l_atr_100',
#  'r_atr_100',
#  'l_atr_150',
#  'r_atr_150',
#  'l_atr_200',
#  'r_atr_200',
#  'chaikin_raw_2_7',
#  'chaikin_raw_4_10',
#  'chaikin_raw_6_15',
#  'chaikin_raw_12_30',
#  'chaikin_raw_20_50',
#  'chaikin_raw_30_75',
#  'chaikin_raw_40_100',
#  'mfi_raw_14',
#  'mfi_raw_21',
#  'mfi_raw_30',
#  'mfi_raw_60',
#  'mfi_raw_100',
#  'mfi_raw_150',
#  'mfi_raw_200',
#  'obv_ema_14',
#  'obv_ema_21',
#  'obv_ema_30',
#  'obv_ema_60',
#  'obv_ema_100',
#  'obv_ema_150',
#  'obv_ema_200',
#  'efi_ema_14',
#  'efi_ema_21',
#  'efi_ema_30',
#  'efi_ema_60',
#  'efi_ema_100',
#  'efi_ema_150',
#  'efi_ema_200',
#  'bbands_upper_raw_14',
#  'bbands_lower_raw_14',
#  'bbands_upper_raw_21',
#  'bbands_lower_raw_21',
#  'bbands_upper_raw_30',
#  'bbands_lower_raw_30',
#  'bbands_upper_raw_60',
#  'bbands_lower_raw_60',
#  'bbands_upper_raw_100',
#  'bbands_lower_raw_100',
#  'bbands_upper_raw_150',
#  'bbands_lower_raw_150',
#  'bbands_upper_raw_200',
#  'bbands_lower_raw_200',
#  'macd_12_26',
#  'macd_7_14',
#  'macd_10_21',
#  'macd_15_30',
#  'macd_30_60',
#  'macd_50_100',
#  'macd_75_150',
#  'macd_100_200',
#  'supertrend_14_2',
#  'supertrend_21_2',
#  'supertrend_30_2',
#  'supertrend_60_2',
#  'supertrend_100_2',
#  'supertrend_150_2',
#  'supertrend_200_2',
#  'vwap',
#  'rsi_14',
#  'rsi_21',
#  'rsi_30',
#  'rsi_60',
#  'rsi_100',
#  'rsi_150',
#  'rsi_200',
#  'Fwd_Ret']

# %%
model_train_dates = sorted(list(set([calendar_util.get_last_training_date(dt, frequency = model_train_freq) for dt in pd.date_range(start=model_start_date, end=end_date, freq='D')])))

# %%
model_prediction_dates = {}

for i, train_date in enumerate(model_train_dates):
    # Determine the start of prediction (day after training)
    pred_start = train_date

    # Determine the end of predictio
    if i + 1 < len(model_train_dates):
        pred_end = model_train_dates[i + 1]
    else:
        pred_end = end_date + pd.Timedelta(days=1)  # include last day

    # Generate prediction date range (exclude train_date itself)
    pred_dates = pd.date_range(start=pred_start, end=pred_end - pd.Timedelta(days=1), freq='D')

    model_prediction_dates[train_date] = pred_dates

# %%
import numpy as np
import pytz
from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Store forward prediction results
forward_predictions = {}

# RidgeCV + Bagging setup

from sklearn.linear_model import RidgeCV
from sklearn.ensemble import BaggingRegressor

# Base RidgeCV model
ridge_base = RidgeCV(
    alphas=[0.1, 1.0, 10.0],
    cv=5
)

# Bagging wrapper (new API uses 'estimator')
ridge_bagging = BaggingRegressor(
    estimator=ridge_base,
    n_estimators=100,
    max_samples=0.7,
    max_features=0.5,
    bootstrap=True,
    bootstrap_features=False,
    n_jobs=-1,
    random_state=42
)

# Example model list — specify type explicitly
model_list = [
    ("LR", "reg", LinearRegression()),
    # ("Ridge_Bagging", "reg", ridge_bagging),
    # ("LGBM_Regression", "reg", LGBMRegressor(
    #     n_estimators=512, learning_rate=0.01, max_depth=-1, random_state=42,
    #     min_child_samples=int(len(dataset_df) * 0.01), min_child_weight=0.01, num_leaves=8, n_jobs=8)
    # )
]

# Threshold for classification target
CLASS_THRESH = 0  # example: predict if label > 0

for train_date in model_train_dates:
    print(f"\nTraining models for {train_date}")

    # In-sample training data
    train_data = get_train_data(dataset_df, train_date, train_lookback_days, lag=1)
    train_data = train_data.replace([np.inf, -np.inf], np.nan).fillna(0)

    X_train = train_data[feature_cols]
    y_train = train_data[label_col]

    if X_train.empty or y_train.empty:
        print("No training data found. Skipping...")
        continue

    y_train_cls = (y_train > CLASS_THRESH).astype(int)
    if y_train_cls.nunique() == 1:
        print("Skipping: constant feature(s) found.")
        continue

    # ---- Train & Collect Predictions ----
    preds_train_all = []
    for name, mtype, model in model_list:
        print(f"Training {name}...")

        if mtype == "clf":
            y_train_cls = (y_train > CLASS_THRESH).astype(int)
            model.fit(X_train, y_train_cls)
            y_pred_train = model.predict_proba(X_train)[:, 1]
        else:
            model.fit(X_train, y_train)
            y_pred_train = model.predict(X_train)

        preds_train_all.append(y_pred_train)

    # Ensemble prediction = mean of all model predictions
    y_pred_train_ensemble = np.mean(preds_train_all, axis=0)

    # In-sample metrics (regression metrics)
    r2 = r2_score(y_train, y_pred_train_ensemble)
    mse = mean_squared_error(y_train, y_pred_train_ensemble)
    mae = mean_absolute_error(y_train, y_pred_train_ensemble)

    print(f"In-sample R² Score: {r2:.10f}")
    print(f"In-sample MSE     : {mse:.10f}")
    print(f"In-sample MAE     : {mae:.10f}")

    # ---- OOS / Forward Predictions ----
    pred_dates = model_prediction_dates[train_date]
    if pred_dates.empty:
        continue

    ASIA_TZ = 'Asia/Kolkata'
    pred_dates = pred_dates.tz_localize(ASIA_TZ)

    mask = (
        (dataset_df['timestamp'] >= pred_dates.min()) &
        (dataset_df['timestamp'] <= pred_dates.max())
    )
    pred_df = dataset_df[mask].copy()
    pred_df = pred_df.replace([np.inf, -np.inf], np.nan).fillna(0)

    if pred_df.empty:
        print("No data available for forward prediction window.")
        continue

    X_pred = pred_df[feature_cols]
    y_true = pred_df[label_col] if label_col in pred_df else None

    preds_oos_all = []
    for name, mtype, model in model_list:
        if mtype == "clf":
            y_pred_oos = model.predict_proba(X_pred)[:, 1]
        else:
            y_pred_oos = model.predict(X_pred)
        preds_oos_all.append(y_pred_oos)

    y_pred_oos_ensemble = np.mean(preds_oos_all, axis=0)

    # Save predictions
    forward_predictions[train_date] = {
        "dates": pred_df['timestamp'].values,
        "predictions": y_pred_oos_ensemble,
        "true": y_true.values if y_true is not None else None
    }

    # OOS metrics
    if y_true is not None and not y_true.isnull().all():
        r2_oos = r2_score(y_true, y_pred_oos_ensemble)
        mse_oos = mean_squared_error(y_true, y_pred_oos_ensemble)
        mae_oos = mean_absolute_error(y_true, y_pred_oos_ensemble)
        print(f"OOS R² Score: {r2_oos:.10f}")
        print(f"OOS MSE     : {mse_oos:.10f}")
        print(f"OOS MAE     : {mae_oos:.10f}")
    else:
        print("Ground truth not available for OOS window.")

# %%
# Collect all prediction results
all_preds = []

for train_date, result in forward_predictions.items():
    dates = result["dates"]
    preds = result["predictions"]
    true_vals = result["true"]

    # Build a temporary DataFrame for each train_date
    temp_df = pd.DataFrame({
        'timestamp': dates,
        'prediction': preds,
        'fwd_ret': true_vals
    })
    temp_df['timestamp'] = pd.to_datetime(temp_df['timestamp']).dt.tz_localize('Asia/Kolkata')

    # Merge with original dataset to bring in features
    merged_df = pd.merge(temp_df, dataset_df[['timestamp'] + feature_cols], on='timestamp', how='left')

    # Append to final list
    all_preds.append(merged_df)

# Combine all into a single DataFrame
final_prediction_df = pd.concat(all_preds, ignore_index=True)

# Optional: sort by timestamp
final_prediction_df = final_prediction_df.sort_values(by='timestamp').reset_index(drop=True)

# %%
final_prediction_df['return'] = np.sign(final_prediction_df['prediction']) * final_prediction_df['fwd_ret'] / len(symbols)

# %%
final_prediction_df['Hit'] = np.sign(final_prediction_df['prediction']) * np.sign(final_prediction_df['fwd_ret'])

# %%
len(final_prediction_df[final_prediction_df['Hit'] > 0])/len(final_prediction_df)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Optional: Ensure DataFrame is sorted by time
final_prediction_df = final_prediction_df.sort_values(by='timestamp')

# Calculate cumulative returns
final_prediction_df['cumulative_return'] = final_prediction_df['return'].cumsum()

# Plot
plt.figure(figsize=(12, 6))
plt.plot(final_prediction_df['timestamp'], final_prediction_df['cumulative_return'], label='PnL Curve', color='blue')

# Formatting
plt.xlabel('Time')
plt.ylabel('Cumulative Return')
plt.title('Predicted Strategy PnL')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
