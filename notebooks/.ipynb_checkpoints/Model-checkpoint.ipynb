# %%
# Basic Dataset

# %%
import datetime
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append('/home/debjitparia/projects/cryptobot/features')
import dataset, calendar_util, fwd_return

# %%
start_date = pd.to_datetime('2022-01-10')
model_start_date = pd.to_datetime('2023-01-04')
end_date = pd.to_datetime('2025-02-28')
port_freq = '1h'  # protfolio rebalance frequency 
feature_bar = '1h' # Features made out of bars
label_bar = '1h' # 
fwd_return_interval = '1h'
local_timezone="Asia/Kolkata"

model_train_freq = 'monthly'
train_lookback_days = 512
feature_cols = ['sma_5',
 'sma_7',
 'sma_14',
 'sma_21',
 'sma_44',
 'sma_63',
 'sma_88',
 'sma_123',
 'sma_178',
 'sma_252',
 'open_diff',
 'high_diff',
 'low_diff',
 'close_diff',
 'prev_open_to_open',
 'prev_open_to_high',
 'prev_open_to_low',
 'prev_open_to_close',
 'prev_high_to_open',
 'prev_high_to_high',
 'prev_high_to_low',
 'prev_high_to_close',
 'prev_low_to_open',
 'prev_low_to_high',
 'prev_low_to_low',
 'prev_low_to_close',
 'prev_close_to_open',
 'prev_close_to_high',
 'prev_close_to_low',
 'prev_close_to_close',
 'ret_1',
 'ret_2',
 'ret_3',
 'ret_4',
 'ret_5',
 'ret_6',
 'ret_7',
 'ret_8',
 'ret_9',
 'ret_10',
 'ret_11',
 'ret_12',
 'ret_13',
 'ret_14',
 'ret_15',
 'ret_16',
 'ret_17',
 'ret_18',
 'ret_19',
 'ret_20',
 'ret_21',
 'ret_22',
 'ret_23',
 'ret_24',
 'ret_25',
 'ret_26',
 'ret_27',
 'ret_28',
 'ret_29',
 'ret_30',
 'ema_close_14',
 'ema_close_21',
 'ema_close_30',
 'ema_close_60',
 'ema_close_100',
 'ema_close_150',
 'ema_close_200',
 'plus_di_14',
 'minus_di_14',
 'adx_14',
 'plus_di_21',
 'minus_di_21',
 'adx_21',
 'plus_di_30',
 'minus_di_30',
 'adx_30',
 'plus_di_60',
 'minus_di_60',
 'adx_60',
 'plus_di_100',
 'minus_di_100',
 'adx_100',
 'plus_di_150',
 'minus_di_150',
 'adx_150',
 'plus_di_200',
 'minus_di_200',
 'adx_200',
 'eom_raw',
 'eom_ema_14',
 'eom_ema_21',
 'eom_ema_30',
 'eom_ema_60',
 'eom_ema_100',
 'eom_ema_150',
 'eom_ema_200',
 'adl_raw',
 'adl_ema_14',
 'adl_ema_21',
 'adl_ema_30',
 'adl_ema_60',
 'adl_ema_100',
 'adl_ema_150',
 'adl_ema_200',
 'cci_raw',
 'cci_ema_14',
 'cci_ema_21',
 'cci_ema_30',
 'cci_ema_60',
 'cci_ema_100',
 'cci_ema_150',
 'cci_ema_200',
 'l_atr_14',
 'r_atr_14',
 'l_atr_21',
 'r_atr_21',
 'l_atr_30',
 'r_atr_30',
 'l_atr_60',
 'r_atr_60',
 'l_atr_100',
 'r_atr_100',
 'l_atr_150',
 'r_atr_150',
 'l_atr_200',
 'r_atr_200',
 'chaikin_raw_2_7',
 'chaikin_raw_4_10',
 'chaikin_raw_6_15',
 'chaikin_raw_12_30',
 'chaikin_raw_20_50',
 'chaikin_raw_30_75',
 'chaikin_raw_40_100',
 'mfi_raw_14',
 'mfi_raw_21',
 'mfi_raw_30',
 'mfi_raw_60',
 'mfi_raw_100',
 'mfi_raw_150',
 'mfi_raw_200',
 'obv_ema_14',
 'obv_ema_21',
 'obv_ema_30',
 'obv_ema_60',
 'obv_ema_100',
 'obv_ema_150',
 'obv_ema_200',
 'efi_ema_14',
 'efi_ema_21',
 'efi_ema_30',
 'efi_ema_60',
 'efi_ema_100',
 'efi_ema_150',
 'efi_ema_200',
 'bbands_upper_raw_14',
 'bbands_lower_raw_14',
 'bbands_upper_raw_21',
 'bbands_lower_raw_21',
 'bbands_upper_raw_30',
 'bbands_lower_raw_30',
 'bbands_upper_raw_60',
 'bbands_lower_raw_60',
 'bbands_upper_raw_100',
 'bbands_lower_raw_100',
 'bbands_upper_raw_150',
 'bbands_lower_raw_150',
 'bbands_upper_raw_200',
 'bbands_lower_raw_200',
 'macd_12_26',
 'macd_7_14',
 'macd_10_21',
 'macd_15_30',
 'macd_30_60',
 'macd_50_100',
 'macd_75_150',
 'macd_100_200',
 'supertrend_14_2',
 'supertrend_21_2',
 'supertrend_30_2',
 'supertrend_60_2',
 'supertrend_100_2',
 'supertrend_150_2',
 'supertrend_200_2',
 'vwap',
 'rsi_14',
 'rsi_21',
 'rsi_30',
 'rsi_60',
 'rsi_100',
 'rsi_150',
 'rsi_200'
]
feature_cols = [c for c in feature_cols if c is not Ellipsis]
label_col = 'Label'

symbols = ['BTCUSDT', 'ETHUSDT', 'SOLUSDT', 'XRPUSDT', 'BNBUSDT']#, 'LINKUSDT', 'DOGEUSDT', 'API3USDT']#, 'BIOUSDT', 'ADAUSDT', 'ENAUSDT']

# %%
import pandas as pd
from datetime import datetime
from joblib import Parallel, delayed
import dataset, label  # your dataset.py with train_data()
import calendar_util  # for get_training_dates

def _train_data_task(symbol, date, feature_bar, port_freq, label_bar, local_timezone):
    """
    Helper task to call train_data safely.
    """
    try:
        label_df = label.label_data(symbol, date, port_freq, label_bar, local_timezone)
        train_df = dataset.train_data(symbol, date, port_freq, feature_bar, local_timezone)
        df = train_df.merge(label_df, on = ['timestamp', 'symbol'])
        if df is not None and not df.empty:
            return df
    except Exception as e:
        print(f"[ERROR] train_data failed for {symbol} on {date}: {e}")
    return None

def create_multi_day_dataset(symbols, dates, port_freq, feature_bar, label_bar, local_timezone="Asia/Kolkata", nproc=4):
    """
    Create combined dataset for multiple symbols and dates in parallel using joblib.

    Parameters
    ----------
    symbols : str or list[str]
        Single symbol or list of trading symbols.
    dates : pd.DatetimeIndex, list, or list-like of dates
        Dates to collect data for.
    port_freq : str
        Interval string, e.g. '15min', '30min'.
    local_timezone : str
        Timezone string.
    nproc : int
        Number of parallel workers.

    Returns
    -------
    pd.DataFrame
        Combined DataFrame of all training data.
    """
    # Normalize symbols and dates to lists
    if hasattr(dates, "__iter__") and not isinstance(dates, (str, bytes)):
        dates = [d.date() for d in pd.to_datetime(dates)]
    else:
        dates = [pd.to_datetime(dates).date()]
    if isinstance(symbols, str):
        symbols = [symbols]
    if isinstance(dates, (pd.DatetimeIndex, list, tuple)):
        dates = list(pd.to_datetime(dates).date)
    else:
        # single date input
        dates = [pd.to_datetime(dates).date()]


    # Create all (symbol, date) pairs
    tasks = [(symbol, date, port_freq, feature_bar, label_bar, local_timezone) for symbol in symbols for date in dates]

    results = Parallel(n_jobs=nproc, backend='loky')(
        delayed(_train_data_task)(symbol, date, port_freq, feature_bar, label_bar, local_timezone) for symbol, date, port_freq, feature_bar, label_bar, local_timezone in tasks
    )

    # Filter out None or empty results
    results = [df for df in results if df is not None and not df.empty]

    if not results:
        print("[WARN] No data collected for any symbol-date pair.")
        return pd.DataFrame()

    combined_df = pd.concat(results, ignore_index=True)
    print(f"[INFO] Combined dataset contains {len(combined_df)} rows from {len(symbols)} symbols and {len(dates)} dates.")
    return combined_df


def get_train_data(df, target_date, lookback_days, lag=2, model_train_freq="weekly"):
    """
    Slice training data from df based on lookback window and lag.

    Parameters
    ----------
    df : pd.DataFrame
        The full dataset containing a 'timestamp' column.
    target_date : datetime or str
        The date to predict for (exclusive from training set).
    lookback_days : int
        How many days to look back for training data.
    lag : int
        Gap (in days) between the last training date and target date.
    model_train_freq : str
        Frequency passed to `calendar_util.get_training_dates`.

    Returns
    -------
    pd.DataFrame
        The filtered training dataset.
    """
    target_date = pd.to_datetime(target_date).date()
    df['date'] = pd.to_datetime(df['timestamp']).dt.date

    training_dates = calendar_util.get_training_dates(
        target_date, lookback_days, lag=lag, frequency=model_train_freq
    )
    return df[df['date'].isin(training_dates)].copy()

# %%
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm
import fwd_return


def _fwd_data_task(symbol, date, port_freq, fwd_return_interval, local_timezone):
    """
    Helper task to call fwd_return.fwd_data safely.
    """
    try:
        df = fwd_return.fwd_data(symbol, date, port_freq, fwd_return_interval, local_timezone)
        if df is not None and not df.empty:
            return df
    except Exception as e:
        print(f"[ERROR] fwd_data failed for {symbol} on {date}: {e}")
    return None


def create_multi_day_fwd_returns(
    symbols, 
    dates, 
    port_freq, 
    fwd_return_interval, 
    local_timezone="Asia/Kolkata", 
    nproc=4
):
    """
    Collect forward return datasets for multiple symbols and dates in parallel.
    Falls back to sequential processing if nproc == 1.
    """
    # Ensure symbols is a list
    if isinstance(symbols, str):
        symbols = [symbols]

    # Normalize dates to list of datetime.date
    if hasattr(dates, "__iter__") and not isinstance(dates, (str, bytes)):
        dates = [pd.to_datetime(d).date() for d in dates]
    else:
        dates = [pd.to_datetime(dates).date()]

    # Create task list
    tasks = [(symbol, date) for symbol in symbols for date in dates]
    print(f"[INFO] Loaded {len(tasks)} tasks for forward return computation.")

    results = []

    if nproc == 1:
        # Sequential execution with tqdm
        for symbol, date in tqdm(tasks, desc="Fetching fwd_return data (sequential)"):
            df = _fwd_data_task(symbol, date, port_freq, fwd_return_interval, local_timezone)
            if df is not None and not df.empty:
                results.append(df)
    else:
        # Parallel execution with tqdm
        results = Parallel(n_jobs=nproc, backend="loky")(
            delayed(_fwd_data_task)(symbol, date, port_freq, fwd_return_interval, local_timezone)
            for symbol, date in tqdm(tasks, desc="Fetching fwd_return data (parallel)")
        )
        # Filter valid DataFrames
        results = [df for df in results if df is not None and not df.empty]

    if not results:
        print("[WARN] No forward return data collected.")
        return pd.DataFrame()

    combined_df = pd.concat(results, ignore_index=True)
    print(f"[INFO] Combined fwd_return dataset contains {len(combined_df)} rows.")
    return combined_df


def merge_with_fwd_returns(
    final_prediction_df, 
    symbols, 
    dates, 
    port_freq, 
    fwd_return_interval, 
    local_timezone="Asia/Kolkata", 
    nproc=4
):
    """
    Wrapper: fetch forward returns and merge into prediction dataframe.
    """
    fwd_ret_df = create_multi_day_fwd_returns(
        symbols, dates, port_freq, fwd_return_interval, local_timezone, nproc=nproc
    )
    if fwd_ret_df.empty:
        print("[WARN] No fwd_return data to merge.")
        return final_prediction_df

    merged = final_prediction_df.merge(fwd_ret_df, on=["timestamp", "symbol"])
    print(f"[INFO] Final merged dataframe contains {len(merged)} rows.")
    return merged

# %%
# dataset_df = _train_data_task('BTCUSDT', datetime(2023, 2, 4), feature_bar, port_freq, label_bar, local_timezone)
# merge_with_fwd_returns(dataset_df, ['BTCUSDT'], [datetime(2023, 2, 4, 15, 30)], port_freq, fwd_return_interval, local_timezone)

# %%
import pandas as pd

# Create a list of dates (date objects)
dates = pd.date_range(start=start_date, end=end_date, freq='D').date

# Now call with list of dates
dataset_df = create_multi_day_dataset(symbols, dates, port_freq, feature_bar, label_bar, nproc=1)
# dataset_df = merge_with_fwd_returns(dataset_df, symbols, dates, port_freq, fwd_return_interval, local_timezone)
# Out:
# [Cache Invalidated] Previous execution failed at label_data_BTCUSDT_2023-03-24_542b7037c9f904abde38921cc656a147
# [ERROR] train_data failed for BTCUSDT on 2023-03-24: Error in label.label_data (hash 542b7037c9f904abde38921cc656a147): Error in fwd_return.compute (hash c165c64495c219f58a403f85e52b7b38): Error in dataloader.get_symbol_snapshot_bar (hash 7b9beb2dbbbacdc1b009af18ecefc868): Not enough 1-minute bars to build a 1h candle for BTCUSDT ending at 2023-03-24 19:00:00+05:30.
# Expected 60, got 15.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_BTCUSDT_20230324-190000_7b9beb2dbbbacdc1b009af18ecefc868/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_ret/compute_BTCUSDT_20230324-180000_c165c64495c219f58a403f85e52b7b38/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/label_data/label_data_BTCUSDT_2023-03-24_542b7037c9f904abde38921cc656a147/cache.pkl
# [Cache Invalidated] Previous execution failed at train_data_BTCUSDT_2023-03-25_1a3fb2cb769a7cb97aa96ae43227cf81
# [ERROR] train_data failed for BTCUSDT on 2023-03-25: Error in dataset.train_data (hash 1a3fb2cb769a7cb97aa96ae43227cf81): Error in sma.get_sma_indicators (hash 60d51b30e2d646ac21086cfe38fff301): Error in dataloader.get_symbol_snapshot_bar (hash dd07c1d2bfb0c1ba926362c51dcb35a7): Not enough 1-minute bars to build a 1h candle for BTCUSDT ending at 2023-03-24 20:00:00+05:30.
# Expected 60, got 30.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_BTCUSDT_20230324-200000_dd07c1d2bfb0c1ba926362c51dcb35a7/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/sma_indicator/get_sma_indicators_BTCUSDT_20230325-010000_60d51b30e2d646ac21086cfe38fff301/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/train_data/train_data_BTCUSDT_2023-03-25_1a3fb2cb769a7cb97aa96ae43227cf81/cache.pkl
# [Cache Invalidated] Previous execution failed at train_data
cache.pkl
# [Cache Invalidated] Previous execution failed at train_data_BNBUSDT_2023-04-03_aba205cca75a1b10019e80b0bffcfcbe
# [ERROR] train_data failed for BNBUSDT on 2023-04-03: Error in dataset.train_data (hash aba205cca75a1b10019e80b0bffcfcbe): Error in sma.get_sma_indicators (hash 9776ac166912cbbe3b0776b43a6f99a9): Error in dataloader.get_symbol_snapshot_bar (hash bdc3c2bf4f1274ee027fb9aa3b093856): Not enough 1-minute bars to build a 1h candle for BNBUSDT ending at 2023-03-24 20:00:00+05:30.
# Expected 60, got 30.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_BNBUSDT_20230324-200000_bdc3c2bf4f1274ee027fb9aa3b093856/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/sma_indicator/get_sma_indicators_BNBUSDT_20230403-010000_9776ac166912cbbe3b0776b43a6f99a9/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/train_data/train_data_BNBUSDT_2023-04-03_aba205cca75a1b10019e80b0bffcfcbe/cache.pkl
# [Cache Invalidated] Previous execution failed at train_data_BNBUSDT_2023-04-04_d7df8f0dda97c368f9385041da0d60dc
# [ERROR] train_data failed for BNBUSDT on 2023-04-04: Error in dataset.train_data (hash d7df8f0dda97c368f9385041da0d60dc): Error in sma.get_sma_indicators (hash e44655211e56ce414dbc2f397c54a623): Error in dataloader.get_symbol_snapshot_bar (hash bdc3c2bf4f1274ee027fb9aa3b093856): Not enough 1-minute bars to build a 1h candle for BNBUSDT ending at 2023-03-24 20:00:00+05:30.
# Expected 60, got 30.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_BNBUSDT_20230324-200000_bdc3c2bf4f1274ee027fb9aa3b093856/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/sma_indicator/get_sma_indicators_BNBUSDT_20230404-010000_e44655211e56ce414dbc2f397c54a623/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/train_data/train_data_BNBUSDT_2023-04-04_d7df8f0dda97c368f9385041da0d60dc/cache.pkl
# [INFO] Combined dataset contains 136080 rows from 5 symbols and 1146 dates.

# %% [markdown]
# # Feature Selection

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.ensemble import BaggingRegressor
from lightgbm import LGBMRegressor
from sklearn.pipeline import Pipeline
from joblib import Parallel, delayed
from math import sqrt
from scipy.stats import norm


# === Custom Transformer for Feature + Label Clipping ===
class OutlierClipper(BaseEstimator, TransformerMixin):
    def __init__(self, feature_cols, label_col=None, method="iqr", factor=1.5):
        self.feature_cols = feature_cols
        self.label_col = label_col
        self.method = method
        self.factor = factor
        self.boundaries_ = {}

    def _compute_bounds(self, values):
        if self.method == "iqr":
            q1, q3 = np.percentile(values, [25, 75])
            iqr = q3 - q1
            return q1 - self.factor * iqr, q3 + self.factor * iqr
        else:  # zscore
            mean, std = values.mean(), values.std()
            return mean - self.factor * std, mean + self.factor * std

    def fit(self, X, y=None):
        X = pd.DataFrame(X, columns=self.feature_cols)

        for col in self.feature_cols:
            values = X[col].dropna()
            self.boundaries_[col] = self._compute_bounds(values)

        if y is not None and self.label_col is not None:
            values = pd.Series(y, name=self.label_col).dropna()
            self.boundaries_[self.label_col] = self._compute_bounds(values)

        return self

    def transform(self, X, y=None):
        X = pd.DataFrame(X, columns=self.feature_cols).copy()

        for col in self.feature_cols:
            lower, upper = self.boundaries_[col]
            X[col] = X[col].clip(lower, upper)

        if y is not None and self.label_col is not None:
            lower, upper = self.boundaries_[self.label_col]
            y = pd.Series(y).clip(lower, upper).values
            return X.values, y

        return X.values

class ClippedPipeline(Pipeline):
    def fit(self, X, y=None, **fit_params):
        clipper = self.named_steps["clipper"]
        clipper.fit(X, y)
        X_clipped, y_clipped = clipper.transform(X, y)
        self.named_steps["ensemble"].fit(X_clipped, y_clipped)
        return self

    def predict(self, X):
        clipper = self.named_steps["clipper"]
        X_clipped = clipper.transform(X)
        preds = self.named_steps["ensemble"].predict(X_clipped)
        if clipper.label_col in clipper.boundaries_:
            lower, upper = clipper.boundaries_[clipper.label_col]
            preds = np.clip(preds, lower, upper)
        return preds

# === Custom Ensemble Wrapper ===
class EnsembleAvg(BaseEstimator, RegressorMixin):
    def __init__(self, models):
        self.models = models

    def fit(self, X, y):
        self.fitted_models_ = []
        for name, model in self.models:
            mdl = clone(model)
            mdl.fit(X, y)
            self.fitted_models_.append((name, mdl))
        return self

    def predict(self, X):
        preds = np.column_stack([mdl.predict(X) for _, mdl in self.fitted_models_])
        return preds.mean(axis=1)


# === Metrics helpers for feature selection (annualised) ===
def sharpe_ratio(pnl, periods_per_year=365):
    pnl = pd.Series(pnl).dropna()
    n = len(pnl)
    if n < 2 or pnl.std(ddof=1) == 0:
        return np.nan
    sr = pnl.mean() / pnl.std(ddof=1) * sqrt(n)
    return sr * sqrt(periods_per_year / n)

def t_stat(pnl, sr_benchmark=0.0, periods_per_year=365):
    r = pd.Series(pnl).dropna()
    n = len(r)
    if n < 2 or r.std(ddof=1) == 0:
        return np.nan

    mu, sig = r.mean(), r.std(ddof=1)
    sr_hat = mu / sig * sqrt(periods_per_year)  # annualised Sharpe

    g3 = r.skew()
    g4 = r.kurtosis() + 3  # Pearson kurtosis

    denom = np.sqrt(max(1e-12, 1 - g3 * sr_hat + ((g4 - 1.0) / 4.0) * (sr_hat ** 2)))
    z = ((sr_hat - sr_benchmark) * np.sqrt(n - 1)) / denom
    return z

def probabilistic_sharpe_ratio(pnl, sr_benchmark=0.0, periods_per_year=365):
    r = pd.Series(pnl).dropna()
    n = len(r)
    if n < 2 or r.std(ddof=1) == 0:
        return np.nan

    mu, sig = r.mean(), r.std(ddof=1)
    sr_hat = mu / sig * sqrt(periods_per_year)  # annualised Sharpe

    g3 = r.skew()
    g4 = r.kurtosis() + 3  # Pearson kurtosis

    denom = np.sqrt(max(1e-12, 1 - g3 * sr_hat + ((g4 - 1.0) / 4.0) * (sr_hat ** 2)))
    z = ((sr_hat - sr_benchmark) * np.sqrt(n - 1)) / denom
    return float(norm.cdf(z))


# === Walkforward LR for pnl ===
# === Volatility-scaled bet sizing ===
def volatility_scaled_bets(pred_series, realized_returns, window=5000, max_sigma=3):
    mu = pred_series.rolling(window).mean()
    sigma = pred_series.rolling(window).std()

    z = (pred_series - mu) / sigma.replace(0, np.nan)
    bet_size = z.clip(-max_sigma, max_sigma).fillna(0)

    pnl = bet_size.shift(1) * realized_returns  # shift to avoid lookahead bias
    return bet_size, pnl


# === Walkforward LR for pnl (with volatility-scaled bets) ===
def walkforward_lr_pnl(train_df, label_df, features, target_col,
                       n_parts=5, min_points=100,
                       bet_window=21, max_sigma=3):
    X, y = train_df[features], label_df[target_col]
    n = len(X)
    if n < 2 * min_points:
        return pd.Series(dtype=float)

    sizes = np.linspace(0, n, n_parts + 1, dtype=int)
    pnl_all = []
    for i in range(len(sizes) - 2):
        tr_s, tr_e = sizes[i], sizes[i + 1]
        te_s, te_e = sizes[i + 1], sizes[i + 2]
        if tr_e - tr_s < min_points or te_e - te_s < min_points:
            continue

        model = LinearRegression().fit(X.iloc[tr_s:tr_e], y.iloc[tr_s:tr_e])
        preds = pd.Series(model.predict(X.iloc[te_s:te_e]),
                          index=y.iloc[te_s:te_e].index)

        # 🔑 Use volatility-scaled bet sizing instead of ±1
        bet_size, pnl = volatility_scaled_bets(preds, y.iloc[te_s:te_e],
                                               window=bet_window,
                                               max_sigma=max_sigma)
        pnl_all.append(pnl)

    return pd.concat(pnl_all) if pnl_all else pd.Series(dtype=float)


# === Feature Selection mixin ===
class FeatureSelectionMixin:
    def feature_selection(self, train_df, label_df, target_col,
                          feature_sets=None, n_parts=5, min_points=100,
                          sr_benchmark=0.0, n_jobs=-1):
        if feature_sets is None:
            feature_sets = [[c] for c in train_df.columns]

        def _eval(fs):
            pnl = walkforward_lr_pnl(train_df, label_df, fs, target_col,
                                     n_parts=n_parts, min_points=min_points)
            if pnl.empty:
                return {'features': tuple(fs), 'sharpe': np.nan,
                        't_stat': np.nan, 'psr': np.nan, 'n_obs': 0, 'pnl': pnl}
            return {
                'features': tuple(fs),
                'sharpe': sharpe_ratio(pnl),
                't_stat': t_stat(pnl),
                'psr': probabilistic_sharpe_ratio(pnl, sr_benchmark),
                'n_obs': len(pnl),
                'pnl': pnl
            }

        results = Parallel(n_jobs=n_jobs)(
            delayed(_eval)(fs) for fs in feature_sets
        )

        summary = pd.DataFrame([{
            'features': r['features'],
            'sharpe': r['sharpe'],
            't_stat': r['t_stat'],
            'psr': r['psr'],
            'n_obs': r['n_obs']
        } for r in results]).sort_values(
            ['psr', 'sharpe', 'n_obs'], ascending=[False, False, False]
        ).reset_index(drop=True)

        pnl_dict = {r['features']: r['pnl'] for r in results}
        return summary, pnl_dict


# === Extended Pipeline with FS ===
class ClippedPipelineWithFS(ClippedPipeline, FeatureSelectionMixin):
    pass


# === Model Builder with FS ===
def ml_model(n_data_len, feature_cols, label_col, with_fs=False):
    ridge_base = Ridge()
    ridge_bagging = BaggingRegressor(
        estimator=ridge_base,
        n_estimators=100,
        max_samples=0.7,
        max_features=0.5,
        bootstrap=True,
        n_jobs=-1,
        random_state=42
    )

    lgbm = LGBMRegressor(
        n_estimators=128, learning_rate=0.01, max_depth=-1, random_state=42,
        min_child_samples=int(0.1 * n_data_len), min_child_weight=0.01,
        num_leaves=8, n_jobs=8
    )

    clipper = OutlierClipper(feature_cols, label_col, method="iqr", factor=1.5)
    pipeline_cls = ClippedPipelineWithFS if with_fs else ClippedPipeline

    pipeline = pipeline_cls([
        ("clipper", clipper),
        ("ensemble", EnsembleAvg([
            ("Ridge_Bagging", ridge_bagging),
            ("LGBM", lgbm),
        ]))
    ])
    return pipeline

# %%
# numeric_cols = train_data.select_dtypes(include=['number']).columns.tolist()

# %%
# numeric_cols

# %%
model_train_dates = sorted(list(set([calendar_util.get_last_training_date(dt, frequency = model_train_freq) for dt in pd.date_range(start=model_start_date, end=end_date, freq='D')])))

# %%
model_prediction_dates = {}

for i, train_date in enumerate(model_train_dates):
    # Determine the start of prediction (day after training)
    pred_start = train_date

    # Determine the end of predictio
    if i + 1 < len(model_train_dates):
        pred_end = model_train_dates[i + 1]
    else:
        pred_end = end_date + pd.Timedelta(days=1)  # include last day

    # Generate prediction date range (exclude train_date itself)
    pred_dates = pd.date_range(start=pred_start, end=pred_end - pd.Timedelta(days=1), freq='D')

    model_prediction_dates[train_date] = pred_dates

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

forward_predictions = {}

CLASS_THRESH = 0  # if you later extend for classifiers

for train_date in model_train_dates:
    print(f"\nTraining models for {train_date}")

    # ----------------------
    # Build training dataset
    # ----------------------
    train_data = get_train_data(dataset_df, train_date, train_lookback_days, lag=1)
    train_data = train_data.replace([np.inf, -np.inf], np.nan).fillna(0)

    if train_data.empty:
        print("No training data found. Skipping...")
        continue

    X_train = train_data[feature_cols]
    y_train = train_data[label_col]

    if y_train.empty:
        print("No training labels found. Skipping...")
        continue

    # ----------------------
    # Initialize model (with FS enabled)
    # ----------------------
    model = ml_model(len(train_data), feature_cols, label_col, with_fs=True)

    # ----------------------
    # Optional: Feature Selection
    # ----------------------
    print("Running feature selection...")
    fs_summary, fs_pnls = model.feature_selection(
        train_df=X_train,
        label_df=y_train.to_frame(),
        target_col=label_col,
        n_parts=6,
        min_points=100,
        n_jobs=-1
    )
    print(fs_summary.head())

    selected_features = list(fs_summary.loc[np.abs(fs_summary["sharpe"]) > 1, "features"].explode())
    if not selected_features:
        selected_features = feature_cols
    
    print(f"Selected {len(selected_features)} features for training.")
    
    # Build model with only selected features
    model = ml_model(len(train_data), selected_features, label_col, with_fs=True)
    
    # Fit
    model.fit(X_train[selected_features].values, y_train.values)

    # ----------------------
    # In-sample evaluation
    # ----------------------
    y_pred_train = model.predict(X_train[selected_features].values)
    r2 = r2_score(y_train, y_pred_train)
    mse = mean_squared_error(y_train, y_pred_train)
    mae = mean_absolute_error(y_train, y_pred_train)

    print(f"In-sample R² Score: {r2:.10f}")
    print(f"In-sample MSE     : {mse:.10f}")
    print(f"In-sample MAE     : {mae:.10f}")

    # ----------------------
    # OOS / Forward Prediction
    # ----------------------
    pred_dates = model_prediction_dates[train_date]
    if pred_dates.empty:
        continue

    ASIA_TZ = 'Asia/Kolkata'
    pred_dates = pred_dates.tz_localize(ASIA_TZ)

    mask = (
        (dataset_df['timestamp'] >= pred_dates.min()) &
        (dataset_df['timestamp'] <= pred_dates.max())
    )
    pred_df = dataset_df[mask].copy()
    pred_df = pred_df.replace([np.inf, -np.inf], np.nan).fillna(0)

    if pred_df.empty:
        print("No data available for forward prediction window.")
        continue

    X_pred = pred_df[selected_features].values
    y_true = pred_df[label_col] if label_col in pred_df else None

    # Predict using pipeline
    y_pred_oos = model.predict(X_pred)
    pred_df["Prediction"] = y_pred_oos
    forward_predictions[train_date] = pred_df

    # ----------------------
    # OOS evaluation
    # ----------------------
    if y_true is not None and not y_true.isnull().all():
        r2_oos = r2_score(y_true, y_pred_oos)
        mse_oos = mean_squared_error(y_true, y_pred_oos)
        mae_oos = mean_absolute_error(y_true, y_pred_oos)
        print(f"OOS R² Score: {r2_oos:.10f}")
        print(f"OOS MSE     : {mse_oos:.10f}")
        print(f"OOS MAE     : {mae_oos:.10f}")
    else:
        print("Ground truth not available for OOS window.")
# Out:
# Training models for 2023-01-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0       (ret_8,)  0.436781  30.259982  1.0  35596
# 1      (rsi_21,)  0.371542  43.706593  1.0  35596
# 2  (mfi_raw_21,)  0.348457  46.177061  1.0  35596
# 3      (ret_11,)  0.315611  33.693039  1.0  35596
# 4      (ret_10,)  0.267787  26.132845  1.0  35596
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 42715, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000080
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0050348120
# In-sample MSE     : 0.0000962859
# In-sample MAE     : 0.0059474466
# OOS R² Score: -0.0051139719
# OOS MSE     : 0.0000740545
# OOS MAE     : 0.0046005568
#
# Training models for 2023-02-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0      (ret_10,)  0.316714  28.601995  1.0  38696
# 1      (rsi_21,)  0.310638  43.600949  1.0  38696
# 2  (mfi_raw_21,)  0.278533  41.537399  1.0  38696
# 3     (rsi_100,)  0.243464  37.098317  1.0  38696
# 4       (ret_8,)  0.235607  28.137474  1.0  38696
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015748 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 46435, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000040
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0045346407
# In-sample MSE     : 0.0000943976
# In-sample MAE     : 0.0058375507
# OOS R² Score: 0.0007302064
# OOS MSE     : 0.0000410628
# OOS MAE     : 0.0040709515
#
# Training models for 2023-03-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0      (rsi_21,)  0.315216  45.203521  1.0  41496
# 1      (ret_10,)  0.309608  29.274703  1.0  41496
# 2  (mfi_raw_21,)  0.262127  41.422841  1.0  41496
# 3  (efi_ema_21,)  0.249793  26.283886  1.0  41496
# 4      (ret_11,)  0.235086  31.590149  1.0  41496
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 49795, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0042198940
# In-sample MSE     : 0.0000907475
# In-sample MAE     : 0.0057144373
# OOS R² Score: -0.0033007028
# OOS MSE     : 0.0000663680
# OOS MAE     : 0.0050183661
#
# Training models for 2023-04-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0      (ret_10,)  0.322230  31.071565  1.0  43800
# 1      (rsi_21,)  0.302145  45.776957  1.0  43800
# 2      (ret_11,)  0.272154  34.391642  1.0  43800
# 3  (mfi_raw_21,)  0.253824  41.938610  1.0  43800
# 4  (efi_ema_21,)  0.241407  27.005099  1.0  43800
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 52560, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0039841110
# In-sample MSE     : 0.0000894628
# In-sample MAE     : 0.0056780734
# OOS R² Score: 0.0016676210
# OOS MSE     : 0.0000398113
# OOS MAE     : 0.0037802589
#
# Training models for 2023-05-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0       (ret_8,)  0.511677  33.216696  1.0  46396
# 1      (rsi_21,)  0.302889  46.925349  1.0  46396
# 2      (ret_10,)  0.298458  31.043243  1.0  46396
# 3      (ret_11,)  0.257597  34.437187  1.0  46396
# 4  (efi_ema_21,)  0.249564  27.844839  1.0  46396
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019904 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 55675, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0038026165
# In-sample MSE     : 0.0000866523
# In-sample MAE     : 0.0055689399
# OOS R² Score: -0.0001550054
# OOS MSE     : 0.0000208877
# OOS MAE     : 0.0028541133
#
# Training models for 2023-06-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0      (rsi_21,)  0.291380  47.373580  1.0  49496
# 1      (ret_10,)  0.269135  30.707193  1.0  49496
# 2      (ret_11,)  0.251194  34.807079  1.0  49496
# 3  (efi_ema_21,)  0.249595  28.396489  1.0  49496
# 4       (ret_8,)  0.247509  31.987483  1.0  49496
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020984 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 59395, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0034716776
# In-sample MSE     : 0.0000825637
# In-sample MAE     : 0.0054001539
# OOS R² Score: -0.0021396582
# OOS MSE     : 0.0000484781
# OOS MAE     : 0.0040267517
#
# Training models for 2023-07-01
# Running feature selection...
#          features    sharpe     t_stat  psr  n_obs
# 0        (ret_8,)  0.542042  33.217756  1.0  50000
# 1       (rsi_21,)  0.296758  46.923693  1.0  50000
# 2  (efi_ema_200,)  0.272110  32.339626  1.0  50000
# 3   (mfi_raw_21,)  0.257532  43.896346  1.0  50000
# 4  (efi_ema_100,)  0.223562  30.419724  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0031442622
# In-sample MSE     : 0.0000794607
# In-sample MAE     : 0.0052423135
# OOS R² Score: -0.0002184204
# OOS MSE     : 0.0000863962
# OOS MAE     : 0.0037773199
#
# Training models for 2023-08-01
# Running feature selection...
#          features    sharpe     t_stat  psr  n_obs
# 0       (rsi_21,)  0.387571  22.306715  1.0  50000
# 1   (mfi_raw_21,)  0.294428  20.262209  1.0  50000
# 2       (ret_10,)  0.248804  28.192482  1.0  50000
# 3  (efi_ema_100,)  0.216424  29.394345  1.0  50000
# 4        (ret_8,)  0.199754  20.976379  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020403 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0028852698
# In-sample MSE     : 0.0000786886
# In-sample MAE     : 0.0050580840
# OOS R² Score: -0.0020513361
# OOS MSE     : 0.0000252110
# OOS MAE     : 0.0028295314
#
# Training models for 2023-09-01
# Running feature selection...
#          features    sharpe     t_stat  psr  n_obs
# 0       (rsi_21,)  0.366001  21.928522  1.0  50000
# 1   (mfi_raw_21,)  0.284464  19.904940  1.0  50000
# 2        (ret_8,)  0.233126  22.080964  1.0  50000
# 3       (ret_10,)  0.204398  25.865057  1.0  50000
# 4  (efi_ema_100,)  0.199801  28.208639  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020403 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 191
# [LightGBM] [Info] Start training from score -0.000022
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0026885860
# In-sample MSE     : 0.0000769033
# In-sample MAE     : 0.0049245793
# OOS R² Score: 0.0000642099
# OOS MSE     : 0.0000169041
# OOS MAE     : 0.0025358011
#
# Training models for 2023-10-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0      (rsi_21,)  0.318674  21.441968  1.0  50000
# 1  (obv_ema_14,)  0.267514  15.825729  1.0  50000
# 2       (ret_8,)  0.250812  21.495130  1.0  50000
# 3  (mfi_raw_21,)  0.243094  19.404176  1.0  50000
# 4  (efi_ema_21,)  0.214362  25.752335  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score -0.000011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0025465373
# In-sample MSE     : 0.0000750389
# In-sample MAE     : 0.0047954526
# OOS R² Score: -0.0009769003
# OOS MSE     : 0.0000358479
# OOS MAE     : 0.0034855619
#
# Training models for 2023-11-01
# Running feature selection...
#          features    sharpe     t_stat  psr  n_obs
# 0   (efi_ema_21,)  0.241305  24.633119  1.0  50000
# 1  (obv_ema_100,)  0.200604  16.914946  1.0  50000
# 2  (macd_50_100,)  0.192390  23.007895  1.0  50000
# 3       (rsi_21,)  0.181568  19.703560  1.0  50000
# 4  (eom_ema_200,)  0.165947  23.684163  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020836 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0020401921
# In-sample MSE     : 0.0000672179
# In-sample MAE     : 0.0045156846
# OOS R² Score: 0.0007252909
# OOS MSE     : 0.0000691598
# OOS MAE     : 0.0050084692
#
# Training models for 2023-12-01
# Running feature selection...
#          features    sharpe     t_stat  psr  n_obs
# 0       (ret_16,)  0.278410  27.120426  1.0  50000
# 1        (ret_8,)  0.251906  19.365771  1.0  50000
# 2  (eom_ema_200,)  0.243508  26.243080  1.0  50000
# 3       (rsi_21,)  0.235266  18.441611  1.0  50000
# 4       (ret_11,)  0.200648  23.728225  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0020482916
# In-sample MSE     : 0.0000608371
# In-sample MAE     : 0.0042896457
# OOS R² Score: -0.0026580323
# OOS MSE     : 0.0000548063
# OOS MAE     : 0.0048126925
#
# Training models for 2024-01-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0      (ret_16,)  0.278044  26.926732  1.0  50000
# 1       (ret_8,)  0.277638  19.207207  1.0  50000
# 2      (rsi_21,)  0.233196  17.990269  1.0  50000
# 3  (obv_ema_60,)  0.201554  15.330862  1.0  50000
# 4      (ret_17,)  0.195783  28.084754  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0018315672
# In-sample MSE     : 0.0000587840
# In-sample MAE     : 0.0041886759
# OOS R² Score: -0.0000370705
# OOS MSE     : 0.0000606868
# OOS MAE     : 0.0047998432
#
# Training models for 2024-02-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0  (obv_ema_30,)  0.295504  14.795877  1.0  50000
# 1      (ret_16,)  0.262653  26.491045  1.0  50000
# 2       (ret_8,)  0.236533  19.020719  1.0  50000
# 3      (rsi_21,)  0.197946  17.919342  1.0  50000
# 4      (ret_18,)  0.187639  18.877916  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0017586591
# In-sample MSE     : 0.0000592560
# In-sample MAE     : 0.0041870353
# OOS R² Score: 0.0004745484
# OOS MSE     : 0.0000341515
# OOS MAE     : 0.0039216361
#
# Training models for 2024-03-01
# Running feature selection...
#                  features    sharpe     t_stat  psr  n_obs
# 0               (ret_16,)  0.284095  26.028403  1.0  50000
# 1                (ret_8,)  0.225943  18.556423  1.0  50000
# 2          (efi_ema_100,)  0.191886  24.407062  1.0  50000
# 3           (efi_ema_30,)  0.181719  24.270166  1.0  50000
# 4  (bbands_upper_raw_14,)  0.169783  10.889390  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020625 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0019924777
# In-sample MSE     : 0.0000569790
# In-sample MAE     : 0.0041031512
# OOS R² Score: 0.0036345570
# OOS MSE     : 0.0001090109
# OOS MAE     : 0.0069157724
#
# Training models for 2024-04-01
# Running feature selection...
#         features    sharpe     t_stat  psr  n_obs
# 0       (ret_8,)  0.241891  19.615825  1.0  50000
# 1  (eom_ema_21,)  0.238332  28.456982  1.0  50000
# 2      (ret_16,)  0.219763  26.904265  1.0  50000
# 3  (efi_ema_21,)  0.179820  23.197287  1.0  50000
# 4      (ret_18,)  0.178042  19.798456  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0023725656
# In-sample MSE     : 0.0000609429
# In-sample MAE     : 0.0042771301
# OOS R² Score: 0.0026862896
# OOS MSE     : 0.0000945339
# OOS MAE     : 0.0057679710
#
# Training models for 2024-05-01
# Running feature selection...
#               features    sharpe     t_stat  psr  n_obs
# 0             (ret_8,)  0.361507  20.488448  1.0  50000
# 1  (prev_low_to_high,)  0.242426   8.917031  1.0  50000
# 2            (ret_14,)  0.206566  22.404127  1.0  50000
# 3            (ret_17,)  0.190555  31.278804  1.0  50000
# 4        (mfi_raw_21,)  0.159522  15.443090  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0027603559
# In-sample MSE     : 0.0000535022
# In-sample MAE     : 0.0041855075
# OOS R² Score: 0.0015960885
# OOS MSE     : 0.0000381235
# OOS MAE     : 0.0040648745
#
# Training models for 2024-06-01
# Running feature selection...
#               features    sharpe     t_stat  psr  n_obs
# 0             (ret_8,)  0.321903  20.336016  1.0  50000
# 1            (ret_14,)  0.258849  23.963956  1.0  50000
# 2  (prev_low_to_high,)  0.231287   8.863740  1.0  50000
# 3            (ret_27,)  0.198798  32.833300  1.0  50000
# 4            (rsi_21,)  0.190744  12.855633  1.0  50000
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 60000, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000091
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0027973792
# In-sample MSE     : 0.0000516530
# In-sample MAE     : 0.0042119949
# OOS R² Score: -0.0024800533
# OOS MSE     : 0.0001100550
# OOS MAE     : 0.0056306534
#
# Training models for 2024-09-01
# Running feature selection...
#                features    sharpe     t_stat  psr  n_obs
# 0  (prev_high_to_open,)  0.234413   9.624261  1.0  51200
# 1              (ret_8,)  0.227463  20.489063  1.0  51200
# 2             (ret_14,)  0.221703  19.923775  1.0  51200
# 3             (rsi_21,)  0.210243  16.388390  1.0  51200
# 4   (prev_low_to_high,)  0.201414  10.091686  1.0  51200
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48450
# [LightGBM] [Info] Number of data points in the train set: 61440, number of used features: 190
# [LightGBM] [Info] Start training from score 0.000070
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0027236717
# In-sample MSE     : 0.0000540963
# In-sample MAE     : 0.0042444458
# OOS R² Score: -0.0005192251
# OOS MSE     : 0.0000304575
# OOS MAE     : 0.0037985110
#
# Training models for 2024-10-01
# Running feature selection...
#     features    sharpe     t_stat  psr  n_obs
# 0   (ret_8,)  0.259986  20.566881  1.0  51200
# 1  (ret_14,)  0.245373  20.067717  1.0  51200
# 2  (rsi_21,)  0.197367  16.243887  1.0  51200
# 3   (ret_4,)  0.186231  36.096842  1.0  51200
# 4  (rsi_14,)  0.168131  18.451611  1.0  51200
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022208 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 61440, number of used features: 191
# [LightGBM] [Info] Start training from score 0.000071
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0026363081
# In-sample MSE     : 0.0000537679
# In-sample MAE     : 0.0042571564
# OOS R² Score: -0.0017746261
# OOS MSE     : 0.0000271898
# OOS MAE     : 0.0034684532
#
# Training models for 2024-11-01
# Running feature selection...
#               features    sharpe     t_stat  psr  n_obs
# 0             (ret_8,)  0.270721  20.450385  1.0  51200
# 1            (ret_14,)  0.188837  19.330894  1.0  51200
# 2            (ret_13,)  0.186199  31.437621  1.0  51200
# 3       (adl_ema_150,)  0.171967  11.856758  1.0  51200
# 4  (prev_low_to_open,)  0.145496   9.823575  1.0  51200
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021718 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 61440, number of used features: 191
# [LightGBM] [Info] Start training from score 0.000078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0025256341
# In-sample MSE     : 0.0000539796
# In-sample MAE     : 0.0042862697
# OOS R² Score: -0.0013122873
# OOS MSE     : 0.0000990700
# OOS MAE     : 0.0064035776
#
# Training models for 2024-12-01
# Running feature selection...
#                features    sharpe     t_stat  psr  n_obs
# 0              (ret_8,)  0.312607  21.353549  1.0  51200
# 1             (rsi_21,)  0.198822  16.901476  1.0  51200
# 2             (ret_14,)  0.198658  20.883578  1.0  51200
# 3             (ret_13,)  0.193194  30.563470  1.0  51200
# 4  (prev_high_to_open,)  0.184323  10.014301  1.0  51200
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021796 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 61440, number of used features: 191
# [LightGBM] [Info] Start training from score 0.000101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0030192938
# In-sample MSE     : 0.0000566382
# In-sample MAE     : 0.0044146128
# OOS R² Score: 0.0026067050
# OOS MSE     : 0.0000990705
# OOS MAE     : 0.0062706625
#
# Training models for 2025-01-01
# Running feature selection...
#                  features    sharpe     t_stat  psr  n_obs
# 0                (ret_8,)  0.376622  30.363658  1.0  51200
# 1  (bbands_upper_raw_14,)  0.284137  44.277956  1.0  51200
# 2      (supertrend_14_2,)  0.281460  45.444365  1.0  51200
# 3      (supertrend_21_2,)  0.273530  45.285748  1.0  51200
# 4      (supertrend_30_2,)  0.260296  43.704941  1.0  51200
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 61440, number of used features: 191
# [LightGBM] [Info] Start training from score 0.000107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0036906607
# In-sample MSE     : 0.0000576255
# In-sample MAE     : 0.0045767495
# OOS R² Score: 0.0042098037
# OOS MSE     : 0.0000755496
# OOS MAE     : 0.0054380459
#
# Training models for 2025-02-01
# Running feature selection...
#                  features    sharpe     t_stat  psr  n_obs
# 0                (ret_8,)  0.404994  31.666783  1.0  51200
# 1      (supertrend_14_2,)  0.248893  43.641301  1.0  51200
# 2     (prev_low_to_open,)  0.245113  44.003604  1.0  51200
# 3  (bbands_upper_raw_14,)  0.240612  41.893541  1.0  51200
# 4      (supertrend_21_2,)  0.234849  42.251003  1.0  51200
# Selected 191 features for training.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022928 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 48705
# [LightGBM] [Info] Number of data points in the train set: 61440, number of used features: 191
# [LightGBM] [Info] Start training from score 0.000120
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# In-sample R² Score: 0.0041091700
# In-sample MSE     : 0.0000606138
# In-sample MAE     : 0.0047354169
# OOS R² Score: -0.0029086297
# OOS MSE     : 0.0001014307
# OOS MAE     : 0.0061394477

# %%
final_prediction_df = forward_predictions
# Collect all prediction results
all_preds = []

for train_date, result in forward_predictions.items():
    temp_df = result[['timestamp', 'symbol', 'Label', 'Prediction']]
    # temp_df['timestamp'] = pd.to_datetime(temp_df['timestamp']).dt.tz_localize('Asia/Kolkata')
    # Merge with original dataset to bring in features
    # Append to final list
    all_preds.append(temp_df)

# Combine all into a single DataFrame
final_prediction_df = pd.concat(all_preds, ignore_index=True)

# Optional: sort by timestamp
final_prediction_df = final_prediction_df.sort_values(by='timestamp').reset_index(drop=True)

# %%
dates = pd.date_range(start=start_date, end=end_date, freq='D').date

final_prediction_df = merge_with_fwd_returns(
    final_prediction_df[['timestamp', 'symbol','Label', 'Prediction']], symbols, dates, port_freq, fwd_return_interval, local_timezone="Asia/Kolkata", nproc=1
)
# Out:
# [INFO] Loaded 5730 tasks for forward return computation.
# Fetching fwd_return data (sequential):   6%|███████                                                                                                                    | 329/5730 [00:00<00:01, 3289.74it/s]
# [Cache Invalidated] Previous execution failed at fwd_data_BTCUSDT_2023-03-24_ad4182db0b6f996efa3865ac97103695
# Fetching fwd_return data (sequential):  11%|██████████████                                                                                                             | 658/5730 [00:00<00:02, 2104.70it/s]
# [ERROR] fwd_data failed for BTCUSDT on 2023-03-24: Error in fwd_return.fwd_data (hash ad4182db0b6f996efa3865ac97103695): Error in fwd_return.compute (hash c165c64495c219f58a403f85e52b7b38): Error in dataloader.get_symbol_snapshot_bar (hash 7b9beb2dbbbacdc1b009af18ecefc868): Not enough 1-minute bars to build a 1h candle for BTCUSDT ending at 2023-03-24 19:00:00+05:30.
# Expected 60, got 15.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_BTCUSDT_20230324-190000_7b9beb2dbbbacdc1b009af18ecefc868/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_ret/compute_BTCUSDT_20230324-180000_c165c64495c219f58a403f85e52b7b38/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_data/fwd_data_BTCUSDT_2023-03-24_ad4182db0b6f996efa3865ac97103695/cache.pkl
# Fetching fwd_return data (sequential):  27%|████████████████████████████████▉                                                                                         | 1546/5730 [00:00<00:00, 4471.89it/s]
# [Cache Invalidated] Previous execution failed at fwd_data_ETHUSDT_2023-03-24_c57862f775557f8e2ad0545cf275e4d6
# [ERROR] fwd_data failed for ETHUSDT on 2023-03-24: Error in fwd_return.fwd_data (hash c57862f775557f8e2ad0545cf275e4d6): Error in fwd_return.compute (hash 4d3819649b8833260d43df4be37d7108): Error in dataloader.get_symbol_snapshot_bar (hash 48364e769c7fec4147ec4a0e28e375db): Not enough 1-minute bars to build a 1h candle for ETHUSDT ending at 2023-03-24 19:00:00+05:30.
# Expected 60, got 15.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_ETHUSDT_20230324-190000_48364e769c7fec4147ec4a0e28e375db/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_ret/compute_ETHUSDT_20230324-180000_4d3819649b8833260d43df4be37d7108/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_data/fwd_data_ETHUSDT_2023-03-24_c57862f775557f8e2ad0545cf275e4d6/cache.pkl
# Fetching fwd_return data (sequential):  47%|█████████████████████████████████████████████████████████▍                                                                | 2696/5730 [00:00<00:00, 4055.52it/s]
# [Cache Invalidated] Previous execution failed at fwd_data_SOLUSDT_2023-03-24_ec09aa9e3886366bdf86f6ecbb3fcba0
# Fetching fwd_return data (sequential):  55%|███████████████████████████████████████████████████████████████████▍                                                      | 3166/5730 [00:00<00:00, 3316.62it/s]
# [ERROR] fwd_data failed for SOLUSDT on 2023-03-24: Error in fwd_return.fwd_data (hash ec09aa9e3886366bdf86f6ecbb3fcba0): Error in fwd_return.compute (hash 81610e0e80918aa68dda8c4f37866f0b): Error in dataloader.get_symbol_snapshot_bar (hash 30ed819f53c01f46471fc18355008227): Not enough 1-minute bars to build a 1h candle for SOLUSDT ending at 2023-03-24 19:00:00+05:30.
# Expected 60, got 15.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_SOLUSDT_20230324-190000_30ed819f53c01f46471fc18355008227/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_ret/compute_SOLUSDT_20230324-180000_81610e0e80918aa68dda8c4f37866f0b/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_data/fwd_data_SOLUSDT_2023-03-24_ec09aa9e3886366bdf86f6ecbb3fcba0/cache.pkl
# [Cache Invalidated] Previous execution failed at fwd_data_XRPUSDT_2023-03-24_afa96fe1f68b876da0c9a09a8ccde6a6
# Fetching fwd_return data (sequential):  68%|██████████████████████████████████████████████████████████████████████████████████▌                                       | 3877/5730 [00:01<00:00, 3249.46it/s]
# [ERROR] fwd_data failed for XRPUSDT on 2023-03-24: Error in fwd_return.fwd_data (hash afa96fe1f68b876da0c9a09a8ccde6a6): Error in fwd_return.compute (hash d0f5e8842f6c0da71c4e52c8eb3bb717): Error in dataloader.get_symbol_snapshot_bar (hash 8e67eff6877771243bcbb0d91eb27605): Not enough 1-minute bars to build a 1h candle for XRPUSDT ending at 2023-03-24 19:00:00+05:30.
# Expected 60, got 15.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_XRPUSDT_20230324-190000_8e67eff6877771243bcbb0d91eb27605/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_ret/compute_XRPUSDT_20230324-180000_d0f5e8842f6c0da71c4e52c8eb3bb717/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_data/fwd_data_XRPUSDT_2023-03-24_afa96fe1f68b876da0c9a09a8ccde6a6/cache.pkl
# Fetching fwd_return data (sequential):  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████                     | 4748/5730 [00:01<00:00, 4352.78it/s]
# [Cache Invalidated] Previous execution failed at fwd_data_BNBUSDT_2023-03-24_a8163d36fd9ffb47a4b06288b71b69cb
# [ERROR] fwd_data failed for BNBUSDT on 2023-03-24: Error in fwd_return.fwd_data (hash a8163d36fd9ffb47a4b06288b71b69cb): Error in fwd_return.compute (hash 4627586b21d5596dc6a72b35419b930d): Error in dataloader.get_symbol_snapshot_bar (hash 498090db24bbb79a5828111b9d8ecd78): Not enough 1-minute bars to build a 1h candle for BNBUSDT ending at 2023-03-24 19:00:00+05:30.
# Expected 60, got 15.
# Possibly the latest candle is still forming — try again after the interval completes.
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/snapshot_bars/get_symbol_snapshot_bar_BNBUSDT_20230324-190000_498090db24bbb79a5828111b9d8ecd78/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_ret/compute_BNBUSDT_20230324-180000_4627586b21d5596dc6a72b35419b930d/cache.pkl
# See cached error at: /home/debjitparia/Cache/cryptobot_fut_check_v2/fwd_data/fwd_data_BNBUSDT_2023-03-24_a8163d36fd9ffb47a4b06288b71b69cb/cache.pkl
# Fetching fwd_return data (sequential): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5730/5730 [00:01<00:00, 3655.27it/s]
# [INFO] Combined fwd_return dataset contains 137400 rows.
# [INFO] Final merged dataframe contains 90485 rows.

# %%
final_prediction_df
# Out:
#                       timestamp   symbol     Label  Prediction   Fwd_Ret
# 0     2023-01-01 00:00:00+05:30  BTCUSDT -0.000299   -0.000011 -0.000299
# 1     2023-01-01 00:00:00+05:30  SOLUSDT  0.000999   -0.000592  0.000999
# 2     2023-01-01 00:00:00+05:30  XRPUSDT  0.000000   -0.000638  0.000000
# 3     2023-01-01 00:00:00+05:30  BNBUSDT  0.000406   -0.000018  0.000406
# 4     2023-01-01 00:00:00+05:30  ETHUSDT  0.000192    0.000038  0.000192
# ...                         ...      ...       ...         ...       ...
# 90480 2025-02-28 00:00:00+05:30  BTCUSDT -0.006530    0.000478 -0.006530
# 90481 2025-02-28 00:00:00+05:30  SOLUSDT -0.013888    0.000105 -0.013888
# 90482 2025-02-28 00:00:00+05:30  ETHUSDT -0.009089    0.000244 -0.009089
# 90483 2025-02-28 00:00:00+05:30  XRPUSDT -0.003433    0.000171 -0.003433
# 90484 2025-02-28 00:00:00+05:30  BNBUSDT -0.002879    0.000160 -0.002879
#
# [90485 rows x 5 columns]

# %%
# final_prediction_df['True_val'].hist()

# %%
final_prediction_df['return'] = np.sign(final_prediction_df['Prediction']) * final_prediction_df['Fwd_Ret'] / len(symbols)
final_prediction_df['Hit'] = np.sign(final_prediction_df['Prediction']) * np.sign(final_prediction_df['Fwd_Ret'])

# %%
# Parameters
bet_window = 21    # rolling window
max_sigma = 3      # cap for bet size

# Rolling mean & std of predictions
mu = final_prediction_df['Prediction'].rolling(bet_window).mean()
sigma = final_prediction_df['Prediction'].rolling(bet_window).std()

# Z-score scaling -> bet size
z = (final_prediction_df['Prediction'] - mu) / sigma.replace(0, np.nan)
bet_size = z.clip(-max_sigma, max_sigma).fillna(0)

# Shift by 1 to avoid lookahead bias
bet_size = bet_size.shift(1).fillna(0)

# Volatility-scaled return
final_prediction_df['return'] = bet_size * final_prediction_df['Fwd_Ret'] / len(symbols)

# Hit rate now based on whether bet direction matches realized return
final_prediction_df['Hit'] = np.sign(bet_size) * np.sign(final_prediction_df['Fwd_Ret'])

# %%
len(final_prediction_df[final_prediction_df['Hit'] > 0])/len(final_prediction_df)
# Out:
# 0.5024921257667017

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Optional: Ensure DataFrame is sorted by time
final_prediction_df = final_prediction_df.sort_values(by='timestamp')

# Calculate cumulative returns
final_prediction_df['cumulative_return'] = final_prediction_df['return'].cumsum()

# Plot
plt.figure(figsize=(12, 6))
plt.plot(final_prediction_df['timestamp'], final_prediction_df['cumulative_return'], label='PnL Curve', color='blue')

# Formatting
plt.xlabel('Time')
plt.ylabel('Cumulative Return')
plt.title('Predicted Strategy PnL')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
